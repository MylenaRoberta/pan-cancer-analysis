# %% [markdown]
# # **Preprocessing Metadata from TCGA-BRCA Project**
# TCGA: The Cancer Genome Atlas
# BRCA: Breast Invasive Carcinoma

# %% [markdown]
# # Importing Libraries and Configurations

# %%
import json
import os
import sys

import numpy as np
import pandas as pd
import requests

# Get the project root (two levels above)
sys.path.append(os.path.abspath(os.path.join('..', '..')))

from config import (
    BRCA_INTERIM_DATA_DIR,
    BRCA_PAPER_FILE_PATH,
    GDC_API_ENDPOINTS,
    GDC_API_REQUESTS_CONSTANTS,
)

# %% [markdown]
# # Function

# %%
def gdc_api_request(endpoint, fields, filters={}, size=1):
    """
    Send a request to a Genomic Data Commons (GDC) API endpoint with the specified parameters.

    Parameters:
    -----------
    endpoint : str
        The URL of the endpoint to send the request to.
    fields : list of str
        A list of fields to include in the response.
    filters : dict, optional
        A dictionary of filters to apply to the request. Default is an empty dictionary.
    size : int, optional
        The number of results to retrieve. Default is 1.

    Returns:
    --------
    list
        A list of hits (data items) retrieved from the endpoint response.
    """
    # Parameters used in the endpoint request
    params = {
        'fields': ','.join(fields),
        'filters': filters,
        'size': str(size)
    }
    
    # Request the objects of interest to the endpoint
    response = requests.post(
        url=endpoint,
        headers={'Content-Type': 'application/json'},
        json=params
    )
    response.raise_for_status()

    # Convert the response content to a JSON
    json_response = json.loads(response.content.decode('utf-8'))

    return json_response['data']['hits']

# %% [markdown]
# # TCGA-BRCA Paper - Supplementary Table 1
# The Cancer Genome Atlas Network. Comprehensive molecular portraits of human breast tumours. Nature 490, 61–70 (2012). https://doi.org/10.1038/nature11412.

# %% [markdown]
# ## Loading and Filtering Data

# %%
# Create the DataFrame of 'Supplementary Table 1' from the TCGA-BRCA paper
df_paper_data = pd.read_excel(
    BRCA_PAPER_FILE_PATH, sheet_name='SuppTable1', skiprows=1
)

# Rename DataFrame columns
columns = dict()
for name in list(df_paper_data.columns):
    columns[name] = name.replace(' ', '_').lower()
df_paper_data = df_paper_data.rename(columns=columns)

# Filter cases of molecular subtypes of interest
df_paper_cases = df_paper_data \
    .query(
        '(pam50_mrna == "Basal-like") or (pam50_mrna == "HER2-enriched") ' +
        'or (pam50_mrna == "Luminal A") or (pam50_mrna == "Luminal B")'
    )
    
# # Flags
# df_paper_data['is_case_of_interest'] = np.where(
#     ((df_paper_data['pam50_mrna'] == 'Basal-like') 
#      | (df_paper_data['pam50_mrna'] == 'HER2-enriched') 
#      | (df_paper_data['pam50_mrna'] == 'Luminal A') 
#      | (df_paper_data['pam50_mrna'] == 'Luminal B')), 1, 0
# )

# %% [markdown]
# ## Paper Cases DataFrame

# %%
# Store the DataFrame in a CSV file
file_name = 'brca-paper-cases.csv'
df_paper_cases.to_csv(f'{BRCA_INTERIM_DATA_DIR}/{file_name}', index=False)

# %%
# Print the DataFrame of cases of interest from the TCGA-BRCA paper
df_paper_cases
# Out:
#     complete_tcga_id  gender  age_at_initial_pathologic_diagnosis er_status  \
# 0       TCGA-A2-A0T2  FEMALE                                 66.0  Negative
# 1       TCGA-A2-A04P  FEMALE                                 36.0  Negative
# 2       TCGA-A1-A0SK  FEMALE                                 54.0  Negative
# 3       TCGA-A2-A0CM  FEMALE                                 40.0  Negative
# 4       TCGA-AR-A1AR  FEMALE                                 50.0  Negative
# ..               ...     ...                                  ...       ...
# 509     TCGA-E2-A15K  FEMALE                                 58.0  Positive
# 510     TCGA-E2-A15L  FEMALE                                 65.0  Positive
# 511     TCGA-E2-A15M  FEMALE                                 66.0  Positive
# 512     TCGA-E2-A15S  FEMALE                                 34.0  Positive
# 513     TCGA-E2-A15T  FEMALE                                 65.0  Positive
#
#     pr_status her2_final_status tumor tumor--t1_coded node node-coded  ...  \
# 0    Negative          Negative    T3         T_Other   N3   Positive  ...
# 1    Negative          Negative    T2         T_Other   N3   Positive  ...
# 2    Negative          Negative    T2         T_Other   N0   Negative  ...
# 3    Negative          Negative    T2         T_Other   N0   Negative  ...
# 4    Negative          Negative    T1              T1   N2   Positive  ...
# ..        ...               ...   ...             ...  ...        ...  ...
# 509  Positive          Negative    T2         T_Other   N1   Positive  ...
# 510  Positive          Negative    T2         T_Other   N0   Negative  ...
# 511  Positive          Negative    T2         T_Other   N0   Negative  ...
# 512  Negative          Negative    T2         T_Other   N1   Positive  ...
# 513  Positive          Negative    T2         T_Other   N0   Negative  ...
#
#      pam50_mrna sigclust_unsupervised_mrna sigclust_intrinsic_mrna  \
# 0    Basal-like                        0.0                   -13.0
# 1    Basal-like                        0.0                   -13.0
# 2    Basal-like                       -6.0                   -13.0
# 3    Basal-like                      -12.0                   -13.0
# 4    Basal-like                        0.0                   -13.0
# ..          ...                        ...                     ...
# 509   Luminal B                       -3.0                   -12.0
# 510   Luminal B                       -3.0                   -12.0
# 511   Luminal B                       -4.0                    -4.0
# 512   Luminal B                       -3.0                   -10.0
# 513   Luminal B                       -3.0                   -10.0
#
#     mirna_clusters methylation_clusters rppa_clusters cn_clusters  \
# 0              3.0                  5.0         Basal         3.0
# 1              5.0                  5.0         Basal         1.0
# 2              5.0                  5.0         Basal         1.0
# 3              4.0                  4.0         Basal         4.0
# 4              5.0                  5.0           NaN         1.0
# ..             ...                  ...           ...         ...
# 509            4.0                  2.0          LumA         2.0
# 510            NaN                  2.0         ReacI         2.0
# 511            6.0                  1.0         ReacI         3.0
# 512            6.0                  4.0        LumA/B         NaN
# 513            2.0                  4.0        LumA/B         NaN
#
#      integrated_clusters_(with_pam50)  integrated_clusters_(no_exp)  \
# 0                                 2.0                           2.0
# 1                                 2.0                           2.0
# 2                                 2.0                           2.0
# 3                                 2.0                           1.0
# 4                                 NaN                           NaN
# ..                                ...                           ...
# 509                               4.0                           3.0
# 510                               NaN                           NaN
# 511                               3.0                           3.0
# 512                               NaN                           NaN
# 513                               NaN                           NaN
#
#      integrated_clusters_(unsup_exp)
# 0                                2.0
# 1                                2.0
# 2                                2.0
# 3                                1.0
# 4                                NaN
# ..                               ...
# 509                              3.0
# 510                              NaN
# 511                              4.0
# 512                              NaN
# 513                              NaN
#
# [514 rows x 30 columns]

# %% [markdown]
# # GDC API Metadata
# GDC: Genomic Data Commons

# %% [markdown]
# ## Status

# %%
# Request the API version and status to the endpoint
response = requests.get(GDC_API_ENDPOINTS['status'])

# Print the response content
try:
    parsed = json.loads(response.content.decode('utf-8'))
    print(json.dumps(parsed, indent=4))
except json.JSONDecodeError:
    print('Response is not valid JSON:')
    print(response.content.decode('utf-8'))
# Out:
# {
#     "commit": "4bb408881e6dc67eca93ff9fd913629a8f2d11c2",
#     "data_release": "Data Release 42.0 - January 30, 2025",
#     "data_release_version": {
#         "major": 42,
#         "minor": 0,
#         "release_date": "2025-01-30"
#     },
#     "status": "OK",
#     "tag": "7.8.5",
#     "version": 1
# }

# %% [markdown]
# ## Projects

# %% [markdown]
# ### Endpoint Response

# %%
# Fields available in the endpoint
fields = [
    'disease_type',
    'name',
    'primary_site',
    'summary.case_count',
    'summary.data_categories.case_count',
    'summary.data_categories.data_category',
    'summary.data_categories.file_count',
    'summary.experimental_strategies.case_count',
    'summary.experimental_strategies.experimental_strategy',
    'summary.experimental_strategies.file_count',
    'summary.file_count',
]

# Filter to be used in the projects endpoint request
filters = {
    'op': 'in',
    'content': {
        'field': 'projects.project_id',
        'value': GDC_API_REQUESTS_CONSTANTS['projects']
    }
}

# Get the response from the projects endpoint request
projects_response = gdc_api_request(
    endpoint=GDC_API_ENDPOINTS['projects'],
    fields=fields,
    filters=filters,
    size=len(GDC_API_REQUESTS_CONSTANTS['projects'])
)

# %% [markdown]
# ### Project DataFrame

# %%
# Create the TCGA-BRCA project DataFrame
df_project = pd.json_normalize(projects_response) \
    .rename(
        columns={
            'id': 'project_id',
            'name': 'project_name',
            'summary.case_count': 'case_count',
            'summary.data_categories': 'data_categories',
            'summary.experimental_strategies': 'experimental_strategies',
            'summary.file_count': 'file_count',
        }
    ) \
    [[
        'project_id',
        'project_name',
        'primary_site',
        'disease_type',
        'case_count',
        'file_count',
        'experimental_strategies',
        'data_categories',
    ]]

# Store the DataFrame in a CSV file
file_name = 'brca-api-project.csv'
df_project.to_csv(f'{BRCA_INTERIM_DATA_DIR}/{file_name}', index=False)

# %%
# Print the TCGA-BRCA project DataFrame
pd.set_option('display.max_colwidth', 900)
df_project
# Out:
#   project_id               project_name primary_site  \
# 0  TCGA-BRCA  Breast Invasive Carcinoma     [Breast]
#
#                                                                                                                                                                                                                                                                    disease_type  \
# 0  [Epithelial Neoplasms, NOS, Adnexal and Skin Appendage Neoplasms, Squamous Cell Neoplasms, Adenomas and Adenocarcinomas, Complex Epithelial Neoplasms, Fibroepithelial Neoplasms, Cystic, Mucinous and Serous Neoplasms, Basal Cell Neoplasms, Ductal and Lobular Neoplasms]
#
#    case_count  file_count  \
# 0        1098       68962
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      experimental_strategies  \
# 0  [{'file_count': 11079, 'case_count': 1095, 'experimental_strategy': 'RNA-Seq'}, {'file_count': 17049, 'case_count': 1072, 'experimental_strategy': 'WXS'}, {'file_count': 3621, 'case_count': 1079, 'experimental_strategy': 'miRNA-Seq'}, {'file_count': 10572, 'case_count': 952, 'experimental_strategy': 'WGS'}, {'file_count': 75, 'case_count': 74, 'experimental_strategy': 'ATAC-Seq'}, {'file_count': 14329, 'case_count': 1098, 'experimental_strategy': 'Genotyping Array'}, {'file_count': 3714, 'case_count': 1097, 'experimental_strategy': 'Methylation Array'}, {'file_count': 919, 'case_count': 881, 'experimental_strategy': 'Reverse Phase Protein Array'}, {'file_count': 1133, 'case_count': 1062, 'experimental_strategy': 'Diagnostic Slide'}, {'file_count': 1978, 'case_count': 1093, 'experimental_strategy': 'Tissue Slide'}]
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     data_categories
# 0  [{'file_count': 19753, 'case_count': 1098, 'data_category': 'Simple Nucleotide Variation'}, {'file_count': 9282, 'case_count': 1098, 'data_category': 'Sequencing Reads'}, {'file_count': 5316, 'case_count': 1098, 'data_category': 'Biospecimen'}, {'file_count': 2288, 'case_count': 1098, 'data_category': 'Clinical'}, {'file_count': 14346, 'case_count': 1098, 'data_category': 'Copy Number Variation'}, {'file_count': 4876, 'case_count': 1097, 'data_category': 'Transcriptome Profiling'}, {'file_count': 3714, 'case_count': 1097, 'data_category': 'DNA Methylation'}, {'file_count': 919, 'case_count': 881, 'data_category': 'Proteome Profiling'}, {'file_count': 2696, 'case_count': 784, 'data_category': 'Somatic Structural Variation'}, {'file_count': 5772, 'case_count': 1098, 'data_category': 'Structural Variation'}]

# %% [markdown]
# ## Cases

# %% [markdown]
# ### Endpoint Response

# %%
# List with the submitter ids of the cases of interest
submitter_ids = df_paper_cases['complete_tcga_id'].to_list()

# Fields of interest for the cases endpoint request
fields = [
    'disease_type',
    'files.data_format',
    'files.data_type',
    'files.file_id',
    'files.experimental_strategy',
    'submitter_id',
]

# Filters to be used in the cases endpoint request
filters = {
    'op': 'and',
    'content': [
        {
            'op': 'in',
            'content': {
                'field': 'project.project_id',
                'value': GDC_API_REQUESTS_CONSTANTS['projects']
            }
        },
        {
            'op': 'in',
            'content': {
                'field': 'disease_type',
                'value': GDC_API_REQUESTS_CONSTANTS['disease_types']
            }  
        },
        {
            'op': 'in',
            'content': {
                'field': 'submitter_id',
                'value': submitter_ids
            }
        }
    ]
}

# Get the response from the cases endpoint request
cases_response = gdc_api_request(
    endpoint=GDC_API_ENDPOINTS['cases'],
    fields=fields,
    filters=filters,
    size=len(submitter_ids)
)

# %% [markdown]
# ### Cases of Interest DataFrame

# %%
# Create the DataFrame of TCGA-BRCA cases of interest with associated files
df_api_cases = pd.json_normalize(cases_response) \
    .rename(columns={'id': 'case_id'}) \
    [['case_id', 'submitter_id', 'disease_type', 'files']]

# Retrieve the molecular subtype classification of cases
df_api_cases = df_api_cases \
    .merge(
        right=df_paper_cases,
        left_on='submitter_id',
        right_on='complete_tcga_id',
        how='inner'
    ) \
    [['case_id', 'submitter_id', 'disease_type', 'pam50_mrna', 'files']]

# %%
# Print the DataFrame of TCGA-BRCA cases of interest with associated files
pd.set_option('display.max_colwidth', 200)
df_api_cases
# Out:
#                                   case_id  submitter_id  \
# 0    de75d0b9-0f47-4732-8df5-05c350cfcd32  TCGA-AN-A0FY
# 1    1fef9454-b3e8-4d9d-a9aa-aa1f1a32b80c  TCGA-E2-A15J
# 2    2021ed1f-dc75-4701-b8b8-1386466e4802  TCGA-BH-A0H7
# 3    20e8106b-1290-4735-abe4-7621e08e3dc8  TCGA-BH-A0E0
# 4    214a4507-d974-4b3e-8525-7408fccc6a0f  TCGA-BH-A0B7
# ..                                    ...           ...
# 500  33919e92-4ea9-47e5-a6f4-36e51845d50f  TCGA-A8-A09N
# 501  34ab0cb8-bf19-4cbb-b4eb-3c45ee5aa60b  TCGA-B6-A0IG
# 502  360d1d6d-cf3e-4c78-b36f-ef5e3160aa6b  TCGA-BH-A0AU
# 503  2cf68894-168b-458b-af4f-53cad72989a8  TCGA-A7-A13F
# 504  36d77496-99f8-4911-ba7c-89fae32662aa  TCGA-A2-A0T5
#
#                      disease_type     pam50_mrna  \
# 0    Ductal and Lobular Neoplasms      Luminal B
# 1    Ductal and Lobular Neoplasms      Luminal A
# 2    Ductal and Lobular Neoplasms      Luminal A
# 3    Ductal and Lobular Neoplasms     Basal-like
# 4    Ductal and Lobular Neoplasms  HER2-enriched
# ..                            ...            ...
# 500  Ductal and Lobular Neoplasms      Luminal B
# 501  Ductal and Lobular Neoplasms      Luminal A
# 502  Ductal and Lobular Neoplasms      Luminal B
# 503  Ductal and Lobular Neoplasms      Luminal B
# 504  Ductal and Lobular Neoplasms      Luminal A
#
#                                                                                                                                                                                                        files
# 0    [{'data_format': 'VCF', 'file_id': '9fe6ffdd-7490-452e-9a68-accf26dda31d', 'data_type': 'Annotated Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'BEDPE', 'file_id': 'da517742...
# 1    [{'data_format': 'BCR Biotab', 'file_id': '0a40467f-9495-4c5b-b56e-3347a3ee0572', 'data_type': 'Clinical Supplement'}, {'data_format': 'VCF', 'file_id': '9e8b82c0-9bac-4489-b32e-faf591e01f86', 'da...
# 2    [{'data_format': 'BAM', 'file_id': 'aba03be3-9b5a-44b3-97a7-d89c37c8b721', 'data_type': 'Aligned Reads', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'TXT', 'file_id': '70a0fb72-e7ca-4fe5-...
# 3    [{'data_format': 'VCF', 'file_id': '7dc9bd4d-3ee6-42af-8b44-fdd29978b769', 'data_type': 'Annotated Somatic Mutation', 'experimental_strategy': 'WGS'}, {'data_format': 'TSV', 'file_id': 'ba1d64b0-3...
# 4    [{'data_format': 'BEDPE', 'file_id': 'a1a6f518-7460-42cb-b32e-350b0398cfdc', 'data_type': 'Structural Rearrangement', 'experimental_strategy': 'WGS'}, {'data_format': 'TSV', 'file_id': 'f50fdcd8-7...
# ..                                                                                                                                                                                                       ...
# 500  [{'data_format': 'TAR', 'file_id': '15fc9a4b-e7d4-4426-b1db-76c714a0ed5e', 'data_type': 'Intermediate Analysis Archive', 'experimental_strategy': 'WGS'}, {'data_format': 'VCF', 'file_id': '9c9b561...
# 501  [{'data_format': 'TXT', 'file_id': '54d189b0-90e9-4770-8983-b9ed9ccb9d7d', 'data_type': 'Allele-specific Copy Number Segment', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'TAR', ...
# 502  [{'data_format': 'VCF', 'file_id': 'ec73e799-e6d8-44b4-b47c-abfe573c8f39', 'data_type': 'Structural Rearrangement', 'experimental_strategy': 'WGS'}, {'data_format': 'PDF', 'file_id': 'fb2fcbdf-cc6...
# 503  [{'data_format': 'BEDPE', 'file_id': '48327159-a47a-4c5f-8434-3a51edeac2cc', 'data_type': 'Structural Rearrangement', 'experimental_strategy': 'WGS'}, {'data_format': 'TXT', 'file_id': '3acfdb09-8...
# 504  [{'data_format': 'BCR Biotab', 'file_id': '0a40467f-9495-4c5b-b56e-3347a3ee0572', 'data_type': 'Clinical Supplement'}, {'data_format': 'TXT', 'file_id': '40d069b7-738c-48f0-bd13-619ea9a3ff29', 'da...
#
# [505 rows x 5 columns]

# %% [markdown]
# ## Files

# %% [markdown]
# ### Expression Quantification Files

# %%
# Explode lists with dictionaries containing case files metadata 
df_eq_files = df_api_cases.explode('files')

# Filter files related to miRNA-Seq or RNA-Seq experimental strategies
key = 'experimental_strategy'
df_eq_files = df_eq_files[
    df_eq_files['files'].apply(
        lambda x: (
            key in x and (x[key] == 'miRNA-Seq' or x[key] == 'RNA-Seq')
        )
    )
]

# Explode dictionary contents with file metadata into columns
df_eq_files = pd.concat(
    objs=[
        df_eq_files.reset_index(drop=True),
        pd.json_normalize(df_eq_files['files'])
    ],
    axis='columns'
)

# Filter isoform (miRNA-Seq) and gene (RNA-Seq) expression quantification files
df_eq_files = df_eq_files \
    .query(
        '(data_type == "Isoform Expression Quantification") ' +
        'or (data_type == "Gene Expression Quantification")'
    ) \
    .reset_index(drop=True) \
    [['file_id', 'case_id', 'experimental_strategy', 'data_type', 'data_format']]

# %%
# Print the DataFrame of TCGA-BRCA expression quantification files
df_eq_files
# Out:
#                                    file_id  \
# 0     e9fe2319-2624-4ac1-9c41-d0ac44608f02
# 1     0a8016e1-0321-4421-a5ad-db2fd9caf7ab
# 2     8437bf97-2354-40cf-8dc4-631c5d7ae63a
# 3     7a4675e7-4174-4561-ae9c-b7636fbea718
# 4     ea1fadc2-1cdc-4658-9619-eeb26ae09da8
# ...                                    ...
# 1130  7c275803-bb6d-4fbc-b851-5fcb393f8496
# 1131  9c87ef50-5854-4f69-820b-9e0b4d46c982
# 1132  8ca0e4c1-92ab-4653-87e0-cdcc630d8db6
# 1133  d5d23d6a-c141-442f-ac4f-714e46b8d9ef
# 1134  1e4fc580-3846-4ece-a88d-55d0d5e2ac2f
#
#                                    case_id experimental_strategy  \
# 0     de75d0b9-0f47-4732-8df5-05c350cfcd32               RNA-Seq
# 1     de75d0b9-0f47-4732-8df5-05c350cfcd32             miRNA-Seq
# 2     1fef9454-b3e8-4d9d-a9aa-aa1f1a32b80c               RNA-Seq
# 3     1fef9454-b3e8-4d9d-a9aa-aa1f1a32b80c             miRNA-Seq
# 4     2021ed1f-dc75-4701-b8b8-1386466e4802               RNA-Seq
# ...                                    ...                   ...
# 1130  2cf68894-168b-458b-af4f-53cad72989a8             miRNA-Seq
# 1131  2cf68894-168b-458b-af4f-53cad72989a8               RNA-Seq
# 1132  2cf68894-168b-458b-af4f-53cad72989a8             miRNA-Seq
# 1133  36d77496-99f8-4911-ba7c-89fae32662aa               RNA-Seq
# 1134  36d77496-99f8-4911-ba7c-89fae32662aa             miRNA-Seq
#
#                               data_type data_format
# 0        Gene Expression Quantification         TSV
# 1     Isoform Expression Quantification         TXT
# 2        Gene Expression Quantification         TSV
# 3     Isoform Expression Quantification         TXT
# 4        Gene Expression Quantification         TSV
# ...                                 ...         ...
# 1130  Isoform Expression Quantification         TXT
# 1131     Gene Expression Quantification         TSV
# 1132  Isoform Expression Quantification         TXT
# 1133     Gene Expression Quantification         TSV
# 1134  Isoform Expression Quantification         TXT
#
# [1135 rows x 5 columns]

# %% [markdown]
# ### Samples Related to Files

# %%
# List with the UUIDs of the files of interest
file_ids = df_eq_files['file_id'].to_list()

# Fields of interest for the files endpoint request
fields = ['cases.samples.tissue_type', 'cases.samples.sample_type']

# Filters to be used in the files endpoint request
filters = {
    'op': 'and',
    'content': [
        {
            'op': 'in',
            'content': {
                'field': 'cases.samples.sample_type',
                'value': GDC_API_REQUESTS_CONSTANTS['sample_types']
            }
        },
        {
            'op': 'in',
            'content': {
                'field': 'file_id',
                'value': file_ids
            }
        }
    ]
}

# Get the response from the files endpoint request
files_response = gdc_api_request(
    endpoint=GDC_API_ENDPOINTS['files'],
    fields=fields,
    filters=filters,
    size=len(file_ids)
)

# %%
# Create the DataFrame of samples related to files
df_files_samples = pd.json_normalize(files_response)

# Explode the lists of dictionaries with samples metadata
df_samples = pd.json_normalize(
    pd.json_normalize(
        pd.json_normalize(
            df_files_samples.explode('cases')['cases']
        )['samples']
    )[0]
)

# Concatenate exploded metadata from samples to the files UUIDs
df_files_samples = pd.concat(
    objs=[df_files_samples, df_samples],
    axis='columns'
)

# Rearrange the columns of the DataFrame
df_files_samples = df_files_samples \
    .rename(columns={'id': 'file_id'}) \
    [['file_id', 'tissue_type', 'sample_type']]

# %%
# Print the DataFrame of samples related to files
df_files_samples
# Out:
#                                    file_id tissue_type    sample_type
# 0     dd0e32d6-4704-4abd-82e4-2041fbc19a79       Tumor  Primary Tumor
# 1     09a491b5-1bfb-47d9-963f-69f6c7e6c1e5       Tumor  Primary Tumor
# 2     f8e5691a-e24d-4dba-873e-9ffa3ca12bb6       Tumor  Primary Tumor
# 3     65654739-bed4-4ea7-b75c-ca1f278adcc9       Tumor  Primary Tumor
# 4     4af55932-ab7a-41e5-aa7f-fb16ab18c629       Tumor  Primary Tumor
# ...                                    ...         ...            ...
# 1120  ed716c0b-4b09-4902-86b8-6955488d60c3       Tumor  Primary Tumor
# 1121  0bc59ba8-158b-4309-b4d5-bb541f892fbf       Tumor  Primary Tumor
# 1122  bc23716d-70e8-486e-b512-8c45654d5d83       Tumor  Primary Tumor
# 1123  8ecef704-ed0f-4700-a34e-46a174033332       Tumor  Primary Tumor
# 1124  79f97f73-b650-49cf-8654-53038a6c0de7       Tumor  Primary Tumor
#
# [1125 rows x 3 columns]

# %% [markdown]
# ### Files of Interest DataFrame

# %%
# Create the DataFrame of TCGA-BRCA files of interest with associated samples
df_files = df_eq_files \
    .merge(
        right=df_files_samples,
        left_on='file_id',
        right_on='file_id',
        how='inner'
    ) \
    [[
        'file_id',
        'case_id',
        'tissue_type',
        'sample_type',
        'experimental_strategy',
        'data_type',
        'data_format',
    ]]

# %%
# Print the DataFrame of TCGA-BRCA files of interest with associated samples
df_files
# Out:
#                                    file_id  \
# 0     e9fe2319-2624-4ac1-9c41-d0ac44608f02
# 1     0a8016e1-0321-4421-a5ad-db2fd9caf7ab
# 2     8437bf97-2354-40cf-8dc4-631c5d7ae63a
# 3     7a4675e7-4174-4561-ae9c-b7636fbea718
# 4     ea1fadc2-1cdc-4658-9619-eeb26ae09da8
# ...                                    ...
# 1120  7c275803-bb6d-4fbc-b851-5fcb393f8496
# 1121  9c87ef50-5854-4f69-820b-9e0b4d46c982
# 1122  8ca0e4c1-92ab-4653-87e0-cdcc630d8db6
# 1123  d5d23d6a-c141-442f-ac4f-714e46b8d9ef
# 1124  1e4fc580-3846-4ece-a88d-55d0d5e2ac2f
#
#                                    case_id tissue_type          sample_type  \
# 0     de75d0b9-0f47-4732-8df5-05c350cfcd32       Tumor        Primary Tumor
# 1     de75d0b9-0f47-4732-8df5-05c350cfcd32       Tumor        Primary Tumor
# 2     1fef9454-b3e8-4d9d-a9aa-aa1f1a32b80c       Tumor        Primary Tumor
# 3     1fef9454-b3e8-4d9d-a9aa-aa1f1a32b80c       Tumor        Primary Tumor
# 4     2021ed1f-dc75-4701-b8b8-1386466e4802      Normal  Solid Tissue Normal
# ...                                    ...         ...                  ...
# 1120  2cf68894-168b-458b-af4f-53cad72989a8       Tumor        Primary Tumor
# 1121  2cf68894-168b-458b-af4f-53cad72989a8       Tumor        Primary Tumor
# 1122  2cf68894-168b-458b-af4f-53cad72989a8      Normal  Solid Tissue Normal
# 1123  36d77496-99f8-4911-ba7c-89fae32662aa       Tumor        Primary Tumor
# 1124  36d77496-99f8-4911-ba7c-89fae32662aa       Tumor        Primary Tumor
#
#      experimental_strategy                          data_type data_format
# 0                  RNA-Seq     Gene Expression Quantification         TSV
# 1                miRNA-Seq  Isoform Expression Quantification         TXT
# 2                  RNA-Seq     Gene Expression Quantification         TSV
# 3                miRNA-Seq  Isoform Expression Quantification         TXT
# 4                  RNA-Seq     Gene Expression Quantification         TSV
# ...                    ...                                ...         ...
# 1120             miRNA-Seq  Isoform Expression Quantification         TXT
# 1121               RNA-Seq     Gene Expression Quantification         TSV
# 1122             miRNA-Seq  Isoform Expression Quantification         TXT
# 1123               RNA-Seq     Gene Expression Quantification         TSV
# 1124             miRNA-Seq  Isoform Expression Quantification         TXT
#
# [1125 rows x 7 columns]

# %% [markdown]
# ## Filtering Cases and Files

# %% [markdown]
# ### Counting Files per Cases

# %%
# Create an acronym for file types
df_files['file_type'] = (
    df_files['experimental_strategy'] + '_' + df_files['tissue_type']
)

# Copy some columns of the files DataFrame
df_file_count = df_files[['case_id', 'file_id', 'file_type']].copy()

# Create numeric flags for the file types
df_file_count['TTmiR'] = np.where(
    df_file_count['file_type'] == 'miRNA-Seq_Tumor', 1, 0
)
df_file_count['TTmRNA'] = np.where(
    df_file_count['file_type'] == 'RNA-Seq_Tumor', 1, 0
)
df_file_count['NTmiR'] = np.where(
    df_file_count['file_type'] == 'miRNA-Seq_Normal', 1, 0
)
df_file_count['NTmRNA'] = np.where(
    df_file_count['file_type'] == 'RNA-Seq_Normal', 1, 0
)

# Sum all file types count columns
df_file_count['file_count'] = (
    df_file_count['TTmiR'] + df_file_count['TTmRNA'] 
    + df_file_count['NTmiR'] + df_file_count['NTmRNA']
)

# Count the total number of file types per case
df_file_count_agg = df_file_count \
    .groupby('case_id') \
    .agg(
        TTmiR_count=pd.NamedAgg(column='TTmiR', aggfunc='sum'),
        TTmRNA_count=pd.NamedAgg(column='TTmRNA', aggfunc='sum'),
        NTmiR_count=pd.NamedAgg(column='NTmiR', aggfunc='sum'),
        NTmRNA_count=pd.NamedAgg(column='NTmRNA', aggfunc='sum'),
        file_count=pd.NamedAgg(column='file_count', aggfunc='sum')
    ) \
    .sort_values(
        by=['file_count', 'TTmiR_count', 'TTmRNA_count', 'NTmiR_count', 'NTmRNA_count'],
        ascending=False
    )

# %%
# Print the DataFrame that aggregates the file types per case
df_file_count_agg.reset_index()
# Out:
#                                   case_id  TTmiR_count  TTmRNA_count  \
# 0    8c7e74e0-71ef-49b8-9217-94b8ef740ef9            3             3
# 1    f130f376-5801-40f9-975d-a7e2f7b5670d            3             3
# 2    8785012f-f73e-4d68-87cf-1d804af32782            3             3
# 3    0bc5744c-5fa3-45bb-87d0-70a02068b392            1             1
# 4    14267783-5624-4fe5-ba81-9d67f1017474            1             1
# ..                                    ...          ...           ...
# 499  cc348a26-ee11-47a4-8b51-de922967e175            0             1
# 500  dfe6db17-cf45-488e-bd3c-b8433d7343ca            0             1
# 501  e3c336f5-c32f-4c5d-81fb-e2408ae145b2            0             1
# 502  ec6930e5-2d83-435a-9a57-a2c5c22caf02            0             1
# 503  f947d67f-4aa2-4eb9-977e-21a5ae563613            0             1
#
#      NTmiR_count  NTmRNA_count  file_count
# 0              1             1           8
# 1              1             1           8
# 2              0             0           6
# 3              1             1           4
# 4              1             1           4
# ..           ...           ...         ...
# 499            0             0           1
# 500            0             0           1
# 501            0             0           1
# 502            0             0           1
# 503            0             0           1
#
# [504 rows x 6 columns]

# %% [markdown]
# ### Cases of Interest DataFrames

# %% [markdown]
# #### Cases with Tumor Tissue Analysis

# %%
# Filter cases by files associated with tumor tissue
df_tumor_cases = df_file_count_agg \
    .query('(TTmiR_count == 1) and (TTmRNA_count == 1)') \
    .reset_index()

# Create the DataFrame of cases of interest with tumor tissue analysis
df_tumor_cases = df_tumor_cases \
    .merge(
        right=df_api_cases,
        left_on='case_id',
        right_on='case_id',
        how='inner'
    ) \
    [['case_id', 'submitter_id', 'disease_type', 'pam50_mrna', 'files']]

# Store the DataFrame in a CSV file
file_name = 'brca-api-cases-tumor-analysis.csv'
df_tumor_cases.to_csv(f'{BRCA_INTERIM_DATA_DIR}/{file_name}', index=False)

# %%
# Print the DataFrame of cases of interest with tumor tissue analysis
df_tumor_cases
# Out:
#                                   case_id  submitter_id  \
# 0    0bc5744c-5fa3-45bb-87d0-70a02068b392  TCGA-BH-A0DG
# 1    14267783-5624-4fe5-ba81-9d67f1017474  TCGA-BH-A0DP
# 2    17baef7c-d97d-4b98-ab53-503ef856523d  TCGA-A7-A0D9
# 3    17c1d42c-cb84-4655-a4cd-b54bae17ecaf  TCGA-E2-A15K
# 4    18eb4dfc-556f-4bf3-a411-4780209ed1e0  TCGA-BH-A0B3
# ..                                    ...           ...
# 481  fb356957-f620-4d99-b675-1355a1d9f932  TCGA-E2-A14O
# 482  fb57c598-b45b-478a-9d34-ca1f050d5b7c  TCGA-BH-A0DS
# 483  fc18d029-9be2-4fa0-9aef-6d647dc55f0b  TCGA-D8-A147
# 484  fcef8cb5-fb2c-4bfb-82cd-6b9f3145182c  TCGA-BH-A0HP
# 485  fe15c48b-116d-461e-9b40-68514730fd18  TCGA-A2-A0CP
#
#                      disease_type  pam50_mrna  \
# 0    Ductal and Lobular Neoplasms   Luminal A
# 1    Ductal and Lobular Neoplasms   Luminal A
# 2    Ductal and Lobular Neoplasms   Luminal A
# 3    Ductal and Lobular Neoplasms   Luminal B
# 4    Ductal and Lobular Neoplasms  Basal-like
# ..                            ...         ...
# 481  Ductal and Lobular Neoplasms   Luminal B
# 482  Ductal and Lobular Neoplasms   Luminal A
# 483  Ductal and Lobular Neoplasms  Basal-like
# 484  Ductal and Lobular Neoplasms   Luminal A
# 485  Ductal and Lobular Neoplasms   Luminal A
#
#                                                                                                                                                                                                        files
# 0    [{'data_format': 'BEDPE', 'file_id': 'f1c01ec0-cf13-4009-a4a1-23665580ab6e', 'data_type': 'Structural Rearrangement', 'experimental_strategy': 'WGS'}, {'data_format': 'BEDPE', 'file_id': '50e7aa21...
# 1    [{'data_format': 'BCR Biotab', 'file_id': '0a40467f-9495-4c5b-b56e-3347a3ee0572', 'data_type': 'Clinical Supplement'}, {'data_format': 'BAM', 'file_id': '15a12710-1f2b-41aa-8cf7-054b67f29fbe', 'da...
# 2    [{'data_format': 'BAM', 'file_id': '8c151dbe-9b21-4fdc-8664-a610ef423606', 'data_type': 'Aligned Reads', 'experimental_strategy': 'WGS'}, {'data_format': 'BEDPE', 'file_id': 'cc14571e-62b5-4f0a-84...
# 3    [{'data_format': 'TXT', 'file_id': 'db86d78c-d6e7-4c62-8942-91b839270b2b', 'data_type': 'Copy Number Segment', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'SVS', 'file_id': '96ce...
# 4    [{'data_format': 'VCF', 'file_id': '9c9e9481-617b-4ecb-8416-07d62453fa8b', 'data_type': 'Structural Rearrangement', 'experimental_strategy': 'WGS'}, {'data_format': 'TXT', 'file_id': '19259452-1a7...
# ..                                                                                                                                                                                                       ...
# 481  [{'data_format': 'SVS', 'file_id': '7846cf1d-aab1-4e14-9f18-f5f7ca4a52bc', 'data_type': 'Slide Image', 'experimental_strategy': 'Tissue Slide'}, {'data_format': 'TXT', 'file_id': '6b9417c3-399d-48...
# 482  [{'data_format': 'SVS', 'file_id': 'f8f16824-4f10-4b71-a8fc-0a2c3176c16a', 'data_type': 'Slide Image', 'experimental_strategy': 'Tissue Slide'}, {'data_format': 'TSV', 'file_id': '0dc31470-2ad5-4e...
# 483  [{'data_format': 'TXT', 'file_id': '7da02dc3-caf0-4809-99f0-8f5cd0ebff0b', 'data_type': 'Allele-specific Copy Number Segment', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'TSV', ...
# 484  [{'data_format': 'VCF', 'file_id': '64c1118e-5ac4-46e1-9475-7499d19a894b', 'data_type': 'Annotated Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'SVS', 'file_id': '3fd44a43-5...
# 485  [{'data_format': 'TXT', 'file_id': '0cb8ce0b-9920-4b0f-962b-68b102f9e6a7', 'data_type': 'Methylation Beta Value', 'experimental_strategy': 'Methylation Array'}, {'data_format': 'TXT', 'file_id': '...
#
# [486 rows x 5 columns]

# %% [markdown]
# #### Cases with Normal Tissue Analysis

# %%
# Filter cases by files associated with normal tissue
df_normal_cases = df_file_count_agg \
    .query('(NTmiR_count == 1) and (NTmRNA_count == 1)') \
    .reset_index()

# Create the DataFrame of cases of interest with normal tissue analysis
df_normal_cases = df_normal_cases \
    .merge(
        right=df_api_cases,
        left_on='case_id',
        right_on='case_id',
        how='inner'
    ) \
    [['case_id', 'submitter_id', 'disease_type', 'pam50_mrna', 'files']]

# Store the DataFrame in a CSV file
file_name = 'brca-api-cases-normal-analysis.csv'
df_normal_cases.to_csv(f'{BRCA_INTERIM_DATA_DIR}/{file_name}', index=False)

# %%
# Print the DataFrame of cases of interest with normal tissue analysis
df_normal_cases
# Out:
#                                  case_id  submitter_id  \
# 0   8c7e74e0-71ef-49b8-9217-94b8ef740ef9  TCGA-A7-A13E
# 1   f130f376-5801-40f9-975d-a7e2f7b5670d  TCGA-A7-A0DB
# 2   0bc5744c-5fa3-45bb-87d0-70a02068b392  TCGA-BH-A0DG
# 3   14267783-5624-4fe5-ba81-9d67f1017474  TCGA-BH-A0DP
# 4   17baef7c-d97d-4b98-ab53-503ef856523d  TCGA-A7-A0D9
# 5   17c1d42c-cb84-4655-a4cd-b54bae17ecaf  TCGA-E2-A15K
# 6   18eb4dfc-556f-4bf3-a411-4780209ed1e0  TCGA-BH-A0B3
# 7   2021ed1f-dc75-4701-b8b8-1386466e4802  TCGA-BH-A0H7
# 8   214a4507-d974-4b3e-8525-7408fccc6a0f  TCGA-BH-A0B7
# 9   21ef1730-e5a7-47ce-b419-d000bb59ae15  TCGA-BH-A1F0
# 10  233b02f3-c4f0-4a67-9db5-e68d5cdaccb6  TCGA-BH-A18U
# 11  24334ac1-28a3-4b61-b590-3f51e375b247  TCGA-BH-A0HK
# 12  2b22db1d-54a1-4b9e-a86e-a174cf51d95c  TCGA-BH-A0BS
# 13  2cf68894-168b-458b-af4f-53cad72989a8  TCGA-A7-A13F
# 14  327a2395-85c8-42e1-9638-8e037a1723ed  TCGA-BH-A0BC
# 15  360d1d6d-cf3e-4c78-b36f-ef5e3160aa6b  TCGA-BH-A0AU
# 16  417dea5f-f68e-4dab-940e-43ae8c67e5e6  TCGA-BH-A1EV
# 17  433427a1-bacf-4381-91ba-5fec8a0953f9  TCGA-BH-A18S
# 18  4510295e-8aa7-4ef1-b2b7-91cc902f8200  TCGA-BH-A1EO
# 19  478eb8aa-50b8-4ce5-98e4-d518ede4b174  TCGA-BH-A0DZ
# 20  4a032bad-e726-48f2-8f39-e3acc109cc91  TCGA-BH-A0BZ
# 21  50619f8c-10aa-464a-a227-90a7aa6ffd43  TCGA-BH-A18K
# 22  518f231c-f5f9-4a39-a97b-7fd5666d3e50  TCGA-BH-A0AZ
# 23  557cb0a3-6f1b-4faf-8296-0a15c24158f9  TCGA-BH-A18P
# 24  59be60a3-e0f6-4d63-b98c-574ef92428c4  TCGA-E2-A15M
# 25  5d1d00c6-fcae-479e-ae1e-de76efd41d98  TCGA-BH-A0BW
# 26  606fbc6a-b41b-441d-9401-51e54912bf5e  TCGA-BH-A0E1
# 27  64089c20-939f-48b4-ae8b-904ad0597145  TCGA-E2-A15I
# 28  665dd3d3-779c-4abd-b5d7-13342340451d  TCGA-BH-A18N
# 29  74f31744-0aed-4633-beec-4e203315f0b7  TCGA-BH-A0DT
# 30  7875018b-91dc-4ab1-83b0-ee3883e2816e  TCGA-BH-A0C0
# 31  7bcf6d42-eb8f-4aa2-825b-38671d4f9e3a  TCGA-BH-A0C3
# 32  87f03d04-e651-4a6e-aea6-1c946aa46202  TCGA-BH-A0BV
# 33  8986a141-eae7-4157-b695-02cc6fc3b071  TCGA-BH-A1ET
# 34  93ed6066-b567-4e1c-ab81-23370f9d3452  TCGA-BH-A0AY
# 35  9d166970-07c8-4ca3-9cfa-ed0049df9ecc  TCGA-BH-A1EW
# 36  9d95a65b-e41d-4f93-92d4-99dce29ff40d  TCGA-A7-A0CE
# 37  9da462b0-93c2-4305-89f6-7199a30399a7  TCGA-BH-A0B5
# 38  9ddc3e7b-8b54-4a83-8335-8053940f56c1  TCGA-BH-A18L
# 39  a1093598-d3a8-4ffe-83fc-bc7d1faff7e5  TCGA-BH-A1EU
# 40  a32cb96a-78bf-456e-a6ab-2d47b2c67ad4  TCGA-BH-A0BT
# 41  a6edb6ca-ae9f-4da7-8ebe-92d83d2987fb  TCGA-E2-A158
# 42  a851ca14-7bbf-455b-a054-ec03979a4247  TCGA-BH-A0DQ
# 43  b3bb8fd6-ee54-4813-b042-2bbe70115382  TCGA-BH-A0BQ
# 44  be9bf36a-12e1-4386-addf-1686dc8b49de  TCGA-E2-A153
# 45  cab38ea8-4555-413c-b81e-4621aac4ef85  TCGA-BH-A0H5
# 46  cc074b7f-d3b2-4880-902e-bf10e667b665  TCGA-BH-A18J
# 47  d3d4d709-ab34-4617-aa8c-51a3d0a3efe6  TCGA-BH-A0DO
# 48  d6f911b5-e895-43f8-8f86-0ac2f1bc6fae  TCGA-BH-A0BJ
# 49  d8492ebd-3d94-4a4b-8de7-386526691cc2  TCGA-E2-A1BC
# 50  db4bc6aa-2e7d-4bcb-8519-a455f624d33b  TCGA-BH-A18Q
# 51  dba9beec-5e51-48c0-9229-0ee286a02a1a  TCGA-BH-A0DD
# 52  e666081b-caaf-4e8b-9446-807be71201a5  TCGA-BH-A0HA
# 53  f2bbfa9d-9a9d-4f46-9fde-378e4c44e2ad  TCGA-BH-A0DK
# 54  f63722c1-a0bb-4bf9-8a10-1d76a8e1a0ba  TCGA-BH-A18M
# 55  f6e1ec78-5ad9-4879-9b7e-262d17b166ad  TCGA-BH-A18R
#
#                     disease_type     pam50_mrna  \
# 0   Ductal and Lobular Neoplasms     Basal-like
# 1   Ductal and Lobular Neoplasms      Luminal A
# 2   Ductal and Lobular Neoplasms      Luminal A
# 3   Ductal and Lobular Neoplasms      Luminal A
# 4   Ductal and Lobular Neoplasms      Luminal A
# 5   Ductal and Lobular Neoplasms      Luminal B
# 6   Ductal and Lobular Neoplasms     Basal-like
# 7   Ductal and Lobular Neoplasms      Luminal A
# 8   Ductal and Lobular Neoplasms  HER2-enriched
# 9   Ductal and Lobular Neoplasms     Basal-like
# 10  Ductal and Lobular Neoplasms      Luminal B
# 11  Ductal and Lobular Neoplasms      Luminal A
# 12  Ductal and Lobular Neoplasms      Luminal A
# 13  Ductal and Lobular Neoplasms      Luminal B
# 14  Ductal and Lobular Neoplasms      Luminal A
# 15  Ductal and Lobular Neoplasms      Luminal B
# 16  Ductal and Lobular Neoplasms  HER2-enriched
# 17  Ductal and Lobular Neoplasms      Luminal A
# 18  Ductal and Lobular Neoplasms      Luminal A
# 19  Ductal and Lobular Neoplasms  HER2-enriched
# 20  Ductal and Lobular Neoplasms      Luminal B
# 21  Ductal and Lobular Neoplasms     Basal-like
# 22  Ductal and Lobular Neoplasms      Luminal A
# 23  Ductal and Lobular Neoplasms  HER2-enriched
# 24  Ductal and Lobular Neoplasms      Luminal B
# 25  Ductal and Lobular Neoplasms     Basal-like
# 26  Ductal and Lobular Neoplasms      Luminal A
# 27  Ductal and Lobular Neoplasms      Luminal A
# 28  Ductal and Lobular Neoplasms      Luminal A
# 29  Ductal and Lobular Neoplasms      Luminal A
# 30  Ductal and Lobular Neoplasms      Luminal B
# 31  Ductal and Lobular Neoplasms      Luminal B
# 32  Ductal and Lobular Neoplasms      Luminal A
# 33  Ductal and Lobular Neoplasms      Luminal A
# 34  Ductal and Lobular Neoplasms      Luminal B
# 35  Ductal and Lobular Neoplasms      Luminal B
# 36  Ductal and Lobular Neoplasms     Basal-like
# 37  Ductal and Lobular Neoplasms      Luminal B
# 38  Ductal and Lobular Neoplasms      Luminal B
# 39  Ductal and Lobular Neoplasms      Luminal A
# 40  Ductal and Lobular Neoplasms      Luminal A
# 41  Ductal and Lobular Neoplasms     Basal-like
# 42  Ductal and Lobular Neoplasms      Luminal A
# 43  Ductal and Lobular Neoplasms      Luminal A
# 44  Ductal and Lobular Neoplasms      Luminal A
# 45  Ductal and Lobular Neoplasms      Luminal A
# 46  Ductal and Lobular Neoplasms      Luminal B
# 47  Ductal and Lobular Neoplasms      Luminal A
# 48  Ductal and Lobular Neoplasms      Luminal A
# 49  Ductal and Lobular Neoplasms      Luminal A
# 50  Ductal and Lobular Neoplasms     Basal-like
# 51  Ductal and Lobular Neoplasms      Luminal B
# 52  Ductal and Lobular Neoplasms      Luminal A
# 53  Ductal and Lobular Neoplasms      Luminal A
# 54  Ductal and Lobular Neoplasms      Luminal A
# 55  Ductal and Lobular Neoplasms  HER2-enriched
#
#                                                                                                                                                                                                       files
# 0   [{'data_format': 'TSV', 'file_id': '767bba1d-e80f-49fa-82b1-075a882d0a10', 'data_type': 'Simple Germline Variation', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'MAF', 'file_id':...
# 1   [{'data_format': 'VCF', 'file_id': '886bfc02-b727-47dd-8806-5a34714f8857', 'data_type': 'Annotated Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'VCF', 'file_id': 'ef67d03e-b...
# 2   [{'data_format': 'BEDPE', 'file_id': 'f1c01ec0-cf13-4009-a4a1-23665580ab6e', 'data_type': 'Structural Rearrangement', 'experimental_strategy': 'WGS'}, {'data_format': 'BEDPE', 'file_id': '50e7aa21...
# 3   [{'data_format': 'BCR Biotab', 'file_id': '0a40467f-9495-4c5b-b56e-3347a3ee0572', 'data_type': 'Clinical Supplement'}, {'data_format': 'BAM', 'file_id': '15a12710-1f2b-41aa-8cf7-054b67f29fbe', 'da...
# 4   [{'data_format': 'BAM', 'file_id': '8c151dbe-9b21-4fdc-8664-a610ef423606', 'data_type': 'Aligned Reads', 'experimental_strategy': 'WGS'}, {'data_format': 'BEDPE', 'file_id': 'cc14571e-62b5-4f0a-84...
# 5   [{'data_format': 'TXT', 'file_id': 'db86d78c-d6e7-4c62-8942-91b839270b2b', 'data_type': 'Copy Number Segment', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'SVS', 'file_id': '96ce...
# 6   [{'data_format': 'VCF', 'file_id': '9c9e9481-617b-4ecb-8416-07d62453fa8b', 'data_type': 'Structural Rearrangement', 'experimental_strategy': 'WGS'}, {'data_format': 'TXT', 'file_id': '19259452-1a7...
# 7   [{'data_format': 'BAM', 'file_id': 'aba03be3-9b5a-44b3-97a7-d89c37c8b721', 'data_type': 'Aligned Reads', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'TXT', 'file_id': '70a0fb72-e7ca-4fe5-...
# 8   [{'data_format': 'BEDPE', 'file_id': 'a1a6f518-7460-42cb-b32e-350b0398cfdc', 'data_type': 'Structural Rearrangement', 'experimental_strategy': 'WGS'}, {'data_format': 'TSV', 'file_id': 'f50fdcd8-7...
# 9   [{'data_format': 'SVS', 'file_id': 'db7e4dc3-e9e1-47bd-ab03-7b48e0b1beaa', 'data_type': 'Slide Image', 'experimental_strategy': 'Tissue Slide'}, {'data_format': 'BCR Biotab', 'file_id': '0a40467f-...
# 10  [{'data_format': 'MAF', 'file_id': '3a53ca7e-b47b-4f3e-b786-4c24b2e8be1a', 'data_type': 'Annotated Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'BAM', 'file_id': 'af8c9c0c-3...
# 11  [{'data_format': 'BCR Biotab', 'file_id': '0a40467f-9495-4c5b-b56e-3347a3ee0572', 'data_type': 'Clinical Supplement'}, {'data_format': 'TSV', 'file_id': '027f1116-0dbe-4bb8-b231-11d9089ef551', 'da...
# 12  [{'data_format': 'MAF', 'file_id': '6ee85029-62ee-4493-bf9d-5907d2d20a66', 'data_type': 'Masked Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'VCF', 'file_id': '2757c162-2525...
# 13  [{'data_format': 'BEDPE', 'file_id': '48327159-a47a-4c5f-8434-3a51edeac2cc', 'data_type': 'Structural Rearrangement', 'experimental_strategy': 'WGS'}, {'data_format': 'TXT', 'file_id': '3acfdb09-8...
# 14  [{'data_format': 'MAF', 'file_id': '3e414df5-6a0d-4658-83a6-cc52f8f47a0c', 'data_type': 'Masked Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'TXT', 'file_id': '17ecfcdf-37a6...
# 15  [{'data_format': 'VCF', 'file_id': 'ec73e799-e6d8-44b4-b47c-abfe573c8f39', 'data_type': 'Structural Rearrangement', 'experimental_strategy': 'WGS'}, {'data_format': 'PDF', 'file_id': 'fb2fcbdf-cc6...
# 16  [{'data_format': 'BCR SSF XML', 'file_id': 'f4bcf109-3db4-424e-9280-9ffb06fed2ed', 'data_type': 'Biospecimen Supplement'}, {'data_format': 'TSV', 'file_id': '18151c98-ace8-46e4-87d4-9f53b7e0268f',...
# 17  [{'data_format': 'VCF', 'file_id': 'ea58448f-f513-4b93-ad47-9716354e1b84', 'data_type': 'Annotated Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'TXT', 'file_id': '0ebbab0f-e...
# 18  [{'data_format': 'BCR Biotab', 'file_id': '0a40467f-9495-4c5b-b56e-3347a3ee0572', 'data_type': 'Clinical Supplement'}, {'data_format': 'SVS', 'file_id': 'f42f1f5e-8022-4fce-a9e2-af2702bac381', 'da...
# 19  [{'data_format': 'BAM', 'file_id': '93c944da-7dc7-480f-a46f-4c8464c21b4a', 'data_type': 'Aligned Reads', 'experimental_strategy': 'WGS'}, {'data_format': 'TSV', 'file_id': 'be6f8b24-e668-41c6-89f7...
# 20  [{'data_format': 'BAM', 'file_id': '3e6d86f2-1456-40f6-9d81-a3995f6d810a', 'data_type': 'Aligned Reads', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'BAM', 'file_id': '0e13e4a0-59ee-423f-...
# 21  [{'data_format': 'TXT', 'file_id': 'c5b7ba42-889d-4b7a-a810-298ae179e9c2', 'data_type': 'Isoform Expression Quantification', 'experimental_strategy': 'miRNA-Seq'}, {'data_format': 'BEDPE', 'file_i...
# 22  [{'data_format': 'VCF', 'file_id': 'cd402e3a-92ba-4ea4-a2c1-172201525fbc', 'data_type': 'Annotated Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'TAR', 'file_id': '2b0655d7-4...
# 23  [{'data_format': 'VCF', 'file_id': '40e9ca92-253b-44a8-b505-409e415e2843', 'data_type': 'Raw Simple Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'BCR Biotab', 'file_id': '0a...
# 24  [{'data_format': 'TSV', 'file_id': 'bdf8478d-e020-4a4e-bf9f-968ca9263536', 'data_type': 'Transcript Fusion', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'MAF', 'file_id': 'e5a36fca-6152-4...
# 25  [{'data_format': 'PDF', 'file_id': '530460f1-12da-4420-8116-64ae9e28caaa', 'data_type': 'Pathology Report'}, {'data_format': 'TXT', 'file_id': 'd0178301-200f-4a66-933b-2c6e21628e25', 'data_type': ...
# 26  [{'data_format': 'TXT', 'file_id': 'f52a43ab-8cf4-4611-a13a-195778748214', 'data_type': 'Isoform Expression Quantification', 'experimental_strategy': 'miRNA-Seq'}, {'data_format': 'BEDPE', 'file_i...
# 27  [{'data_format': 'TXT', 'file_id': 'e95cf838-e963-4270-b2ac-0c189b6d496e', 'data_type': 'Isoform Expression Quantification', 'experimental_strategy': 'miRNA-Seq'}, {'data_format': 'TSV', 'file_id'...
# 28  [{'data_format': 'TSV', 'file_id': '78ecb795-9903-44bf-b018-764079b35c4d', 'data_type': 'Protein Expression Quantification', 'experimental_strategy': 'Reverse Phase Protein Array'}, {'data_format'...
# 29  [{'data_format': 'TXT', 'file_id': 'cd64d031-39e6-4e5a-a058-cc8723be8e99', 'data_type': 'Allele-specific Copy Number Segment', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'BCR SS...
# 30  [{'data_format': 'BAM', 'file_id': 'c7dda1c9-6745-4645-9751-ab22f17b30f8', 'data_type': 'Aligned Reads', 'experimental_strategy': 'miRNA-Seq'}, {'data_format': 'MAF', 'file_id': '8340167b-18ef-4c6...
# 31  [{'data_format': 'BCR Biotab', 'file_id': '0a40467f-9495-4c5b-b56e-3347a3ee0572', 'data_type': 'Clinical Supplement'}, {'data_format': 'TXT', 'file_id': 'f8d84812-2fae-449f-9c2a-d38b1c172471', 'da...
# 32  [{'data_format': 'VCF', 'file_id': '3d7c7b87-f375-447a-b505-c881649e2f2c', 'data_type': 'Annotated Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'TSV', 'file_id': 'ea99e4b0-8...
# 33  [{'data_format': 'TXT', 'file_id': '490e2975-d4e5-470d-a8d9-9b17940bd3f0', 'data_type': 'Methylation Beta Value', 'experimental_strategy': 'Methylation Array'}, {'data_format': 'BCR Biotab', 'file...
# 34  [{'data_format': 'CEL', 'file_id': '4688be11-ed2c-4e5b-9cf5-3e93eb27999c', 'data_type': 'Raw Intensities', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'TSV', 'file_id': '4e747f65...
# 35  [{'data_format': 'TXT', 'file_id': '5a28ab87-b8af-4db3-a8f1-b7c8a3ecf0ca', 'data_type': 'Methylation Beta Value', 'experimental_strategy': 'Methylation Array'}, {'data_format': 'BCR Biotab', 'file...
# 36  [{'data_format': 'BAM', 'file_id': '7c0cb406-5de2-4e75-855a-907dc692205c', 'data_type': 'Aligned Reads', 'experimental_strategy': 'WGS'}, {'data_format': 'TSV', 'file_id': 'fc670e63-94de-4930-b3ea...
# 37  [{'data_format': 'TXT', 'file_id': '56e27f97-4797-4e5a-a84b-ed5709558df2', 'data_type': 'Allele-specific Copy Number Segment', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'BAM', ...
# 38  [{'data_format': 'TXT', 'file_id': '2f02bb84-bc0e-449d-9cd0-4b7cf0e4ba54', 'data_type': 'Copy Number Segment', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'SVS', 'file_id': '17c0...
# 39  [{'data_format': 'BAM', 'file_id': '4dc2af8b-95f4-4a54-8a82-8da9fce23b74', 'data_type': 'Aligned Reads', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'BEDPE', 'file_id': 'c2cfb9b0-25df-44c...
# 40  [{'data_format': 'TSV', 'file_id': '68cc7ff0-92b1-4e29-b729-ca582776301b', 'data_type': 'Transcript Fusion', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'SVS', 'file_id': '2c83bc8f-ac3c-4...
# 41  [{'data_format': 'TSV', 'file_id': '62a52136-b629-4049-b3c0-ea77cef0ee0c', 'data_type': 'Simple Germline Variation', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'BCR Biotab', 'fi...
# 42  [{'data_format': 'TSV', 'file_id': 'c642f518-6ba5-4c90-9f0c-0bad0ed80199', 'data_type': 'Gene Expression Quantification', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'BAM', 'file_id': '64...
# 43  [{'data_format': 'BCR Biotab', 'file_id': '0a40467f-9495-4c5b-b56e-3347a3ee0572', 'data_type': 'Clinical Supplement'}, {'data_format': 'BAM', 'file_id': 'cfa351d1-297c-40ae-a6d4-1ddc93f20af9', 'da...
# 44  [{'data_format': 'TSV', 'file_id': 'e4add373-d8c4-447b-85b0-f1e8922e2901', 'data_type': 'Protein Expression Quantification', 'experimental_strategy': 'Reverse Phase Protein Array'}, {'data_format'...
# 45  [{'data_format': 'MAF', 'file_id': '5847a246-65dc-456a-a0af-a5fdb6f4dabc', 'data_type': 'Annotated Somatic Mutation', 'experimental_strategy': 'WXS'}, {'data_format': 'TXT', 'file_id': '1171593e-7...
# 46  [{'data_format': 'SVS', 'file_id': '3984bf8d-e842-46b7-a639-46b7dea4149a', 'data_type': 'Slide Image', 'experimental_strategy': 'Tissue Slide'}, {'data_format': 'BAM', 'file_id': '77d40f65-fca4-49...
# 47  [{'data_format': 'BCR XML', 'file_id': '425014ce-d400-4086-9687-c91c5f1a05bc', 'data_type': 'Clinical Supplement'}, {'data_format': 'VCF', 'file_id': 'ed4bcdde-a76b-4f08-a8ea-84d8b6ae1a90', 'data_...
# 48  [{'data_format': 'TSV', 'file_id': '1f1ad68d-27d9-40a4-a4cd-2e4810d472cf', 'data_type': 'Gene Level Copy Number', 'experimental_strategy': 'Genotyping Array'}, {'data_format': 'BCR Biotab', 'file_...
# 49  [{'data_format': 'TAR', 'file_id': '9719ffe7-5154-44fb-8709-eb7dba9e6e34', 'data_type': 'Intermediate Analysis Archive', 'experimental_strategy': 'WGS'}, {'data_format': 'TSV', 'file_id': '42fd957...
# 50  [{'data_format': 'TSV', 'file_id': '1b9a86e0-b97f-49ba-b227-88022c3f7537', 'data_type': 'Transcript Fusion', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'BCR XML', 'file_id': '00a6f39d-76...
# 51  [{'data_format': 'BEDPE', 'file_id': 'c83c4c6c-0427-46fd-8096-93fd4fa9b17f', 'data_type': 'Transcript Fusion', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'MAF', 'file_id': '5fc15367-ac66...
# 52  [{'data_format': 'BAM', 'file_id': 'f44ad7c7-ed0b-4082-9a11-5e2b479cb061', 'data_type': 'Aligned Reads', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'TXT', 'file_id': '7d1d9d40-75b4-4f55-...
# 53  [{'data_format': 'TXT', 'file_id': '71b9896d-73fb-4f32-8e6e-e5d839095961', 'data_type': 'miRNA Expression Quantification', 'experimental_strategy': 'miRNA-Seq'}, {'data_format': 'BCR Biotab', 'fil...
# 54  [{'data_format': 'TXT', 'file_id': '0d8cf5ce-92ba-40ab-a817-a33ff1b5262b', 'data_type': 'Methylation Beta Value', 'experimental_strategy': 'Methylation Array'}, {'data_format': 'TSV', 'file_id': '...
# 55  [{'data_format': 'TSV', 'file_id': 'bd239a8e-56e2-45ca-bc44-bff98b72c1d6', 'data_type': 'Gene Expression Quantification', 'experimental_strategy': 'RNA-Seq'}, {'data_format': 'TSV', 'file_id': 'db...

# %% [markdown]
# ### Files of Interest DataFrames

# %% [markdown]
# #### Files Associated with Tumor Tissue Analysis

# %%
# List with the UUIDs of the cases of interest with tumor tissue analysis
tumor_cases = df_tumor_cases['case_id'].tolist()

# Create the DataFrame of files of interest associated with tumor tissue analysis
df_tumor_files = df_files \
    .query('(tissue_type == "Tumor") and (case_id == @tumor_cases)') \
    .drop(columns='file_type') \
    .reset_index(drop=True)

# Store the DataFrame in a CSV file
file_name = 'brca-api-files-tumor-analysis.csv'
df_tumor_files.to_csv(f'{BRCA_INTERIM_DATA_DIR}/{file_name}', index=False)

# %%
# Print the DataFrame of files of interest associated with tumor tissue analysis
df_tumor_files
# Out:
#                                   file_id  \
# 0    e9fe2319-2624-4ac1-9c41-d0ac44608f02
# 1    0a8016e1-0321-4421-a5ad-db2fd9caf7ab
# 2    8437bf97-2354-40cf-8dc4-631c5d7ae63a
# 3    7a4675e7-4174-4561-ae9c-b7636fbea718
# 4    15f5f60a-13f0-41a2-8711-171d19c2903a
# ..                                    ...
# 967  8c884351-1c8b-47ff-8bef-1a4f25f645fb
# 968  7c275803-bb6d-4fbc-b851-5fcb393f8496
# 969  9c87ef50-5854-4f69-820b-9e0b4d46c982
# 970  d5d23d6a-c141-442f-ac4f-714e46b8d9ef
# 971  1e4fc580-3846-4ece-a88d-55d0d5e2ac2f
#
#                                   case_id tissue_type    sample_type  \
# 0    de75d0b9-0f47-4732-8df5-05c350cfcd32       Tumor  Primary Tumor
# 1    de75d0b9-0f47-4732-8df5-05c350cfcd32       Tumor  Primary Tumor
# 2    1fef9454-b3e8-4d9d-a9aa-aa1f1a32b80c       Tumor  Primary Tumor
# 3    1fef9454-b3e8-4d9d-a9aa-aa1f1a32b80c       Tumor  Primary Tumor
# 4    2021ed1f-dc75-4701-b8b8-1386466e4802       Tumor  Primary Tumor
# ..                                    ...         ...            ...
# 967  360d1d6d-cf3e-4c78-b36f-ef5e3160aa6b       Tumor  Primary Tumor
# 968  2cf68894-168b-458b-af4f-53cad72989a8       Tumor  Primary Tumor
# 969  2cf68894-168b-458b-af4f-53cad72989a8       Tumor  Primary Tumor
# 970  36d77496-99f8-4911-ba7c-89fae32662aa       Tumor  Primary Tumor
# 971  36d77496-99f8-4911-ba7c-89fae32662aa       Tumor  Primary Tumor
#
#     experimental_strategy                          data_type data_format
# 0                 RNA-Seq     Gene Expression Quantification         TSV
# 1               miRNA-Seq  Isoform Expression Quantification         TXT
# 2                 RNA-Seq     Gene Expression Quantification         TSV
# 3               miRNA-Seq  Isoform Expression Quantification         TXT
# 4                 RNA-Seq     Gene Expression Quantification         TSV
# ..                    ...                                ...         ...
# 967               RNA-Seq     Gene Expression Quantification         TSV
# 968             miRNA-Seq  Isoform Expression Quantification         TXT
# 969               RNA-Seq     Gene Expression Quantification         TSV
# 970               RNA-Seq     Gene Expression Quantification         TSV
# 971             miRNA-Seq  Isoform Expression Quantification         TXT
#
# [972 rows x 7 columns]

# %% [markdown]
# #### Files Associated with Normal Tissue Analysis

# %%
# List with the UUIDs of the cases of interest with normal tissue analysis
normal_cases = df_normal_cases['case_id'].tolist()

# Create the DataFrame of files of interest associated with normal tissue analysis
df_normal_files = df_files \
    .query('(tissue_type == "Normal") and (case_id == @normal_cases)') \
    .drop(columns='file_type') \
    .reset_index(drop=True)

# Store the DataFrame in a CSV file
file_name = 'brca-api-files-normal-analysis.csv'
df_normal_files.to_csv(f'{BRCA_INTERIM_DATA_DIR}/{file_name}', index=False)

# %%
# Print the DataFrame of files of interest associated with normal tissue analysis
df_normal_files
# Out:
#                                   file_id  \
# 0    ea1fadc2-1cdc-4658-9619-eeb26ae09da8
# 1    ef076f15-36a4-4e8a-a624-8cdeb9c4fa2d
# 2    3f5ad0e5-ab95-4c1e-8dfe-09cab1d1500c
# 3    3071e512-94ea-4820-9573-668235188e34
# 4    8790fe0b-8d3a-4f2c-8201-1231da243697
# ..                                    ...
# 107  d4a3af62-0505-49f6-9f34-168bec5cb0d0
# 108  cd746011-8fd7-473d-84e7-f39ec60b6717
# 109  f24d6e88-634e-4d86-b993-76a40f1190d0
# 110  4c2bb8e3-2527-466b-a3bb-0f36c3b2a3e7
# 111  8ca0e4c1-92ab-4653-87e0-cdcc630d8db6
#
#                                   case_id tissue_type          sample_type  \
# 0    2021ed1f-dc75-4701-b8b8-1386466e4802      Normal  Solid Tissue Normal
# 1    2021ed1f-dc75-4701-b8b8-1386466e4802      Normal  Solid Tissue Normal
# 2    214a4507-d974-4b3e-8525-7408fccc6a0f      Normal  Solid Tissue Normal
# 3    214a4507-d974-4b3e-8525-7408fccc6a0f      Normal  Solid Tissue Normal
# 4    21ef1730-e5a7-47ce-b419-d000bb59ae15      Normal  Solid Tissue Normal
# ..                                    ...         ...                  ...
# 107  a851ca14-7bbf-455b-a054-ec03979a4247      Normal  Solid Tissue Normal
# 108  360d1d6d-cf3e-4c78-b36f-ef5e3160aa6b      Normal  Solid Tissue Normal
# 109  360d1d6d-cf3e-4c78-b36f-ef5e3160aa6b      Normal  Solid Tissue Normal
# 110  2cf68894-168b-458b-af4f-53cad72989a8      Normal  Solid Tissue Normal
# 111  2cf68894-168b-458b-af4f-53cad72989a8      Normal  Solid Tissue Normal
#
#     experimental_strategy                          data_type data_format
# 0                 RNA-Seq     Gene Expression Quantification         TSV
# 1               miRNA-Seq  Isoform Expression Quantification         TXT
# 2               miRNA-Seq  Isoform Expression Quantification         TXT
# 3                 RNA-Seq     Gene Expression Quantification         TSV
# 4               miRNA-Seq  Isoform Expression Quantification         TXT
# ..                    ...                                ...         ...
# 107             miRNA-Seq  Isoform Expression Quantification         TXT
# 108             miRNA-Seq  Isoform Expression Quantification         TXT
# 109               RNA-Seq     Gene Expression Quantification         TSV
# 110               RNA-Seq     Gene Expression Quantification         TSV
# 111             miRNA-Seq  Isoform Expression Quantification         TXT
#
# [112 rows x 7 columns]
