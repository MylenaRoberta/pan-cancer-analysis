# %% [markdown]
# # **Processing Interaction Data from miRWalk**

# %% [markdown]
# # Importing Libraries and Configurations

# %%
import logging
import os
import sys
import time

import numpy as np
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import (
    ElementNotInteractableException,
    NoSuchElementException,
)
from selenium.webdriver.support.ui import Select

# Configure basic logging
logging.basicConfig(level=logging.INFO, format='%(levelname)s:%(message)s')

# Add project root to Python's path
sys.path.append(os.path.abspath(os.path.join('..', '..')))

from config import (
    AGGREGATED_READS_FILES,
    BRCA_PROCESSED_FILES_DIRS,
    MIRWALK_DEFAULT_FILE_PATH,
    MIRWALK_DOWNLOAD_PARAMETERS,
    MIRWALK_EXTERNAL_DATA_DIR,
    MIRWALK_MIR_MAPPING_FILE_PATH,
    MIRWALK_PROCESSED_DATA_DIR,
)

# %% [markdown]
# # Functions

# %%
def create_chrome_webdriver():
    """
    Initialize and configure a headless Chrome WebDriver instance for Selenium.

    Returns:
    --------
    selenium.webDriver.Chrome
        An instance of the configured Chrome WebDriver.
    
    Configuration:
    --------
        - Headless Mode: The browser runs without a GUI (`--headless`).
        - No Sandbox: Disables the Chrome sandbox for compatibility (`--no-sandbox`).
        - Dev SHM Usage: Prevents issues with shared memory in containerized 
          environments (`--disable-dev-shm-usage`).
        - GPU: Disables GPU acceleration (`--disable-gpu`).
        - Extensions: Disables browser extensions (`--disable-extensions`).
        - Download Directory: Sets the default download directory.
    """
    # Configure the Selenium ChromeDriver
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')
    options.add_argument('--no-sandbox')
    options.add_argument('--disable-dev-shm-usage')
    options.add_argument('--disable-gpu')
    options.add_argument('--disable-extensions')

    # Define the download directory
    options.add_experimental_option(
        'prefs', {'download.default_directory': MIRWALK_EXTERNAL_DATA_DIR}
    )

    # Initiate the Chrome browser
    driver = webdriver.Chrome(options=options)

    return driver

# %%
def exporting_mir_targets_file(driver, accession_id, max_wait_time=60):
    """
    Automate the download of microRNA target interaction data from the miRWalk website.

    Parameters:
    -----------
    driver : selenium.webdriver.Chrome
        The WebDriver instance to control the browser.
    accession_id : str
        The accession ID of the microRNA to search for.
    max_wait_time : int
        Maximum time in seconds to wait for the download to complete (default is 60).
    """
    logging.info(f'Downloading the interactions of microRNA {accession_id}...')
    
    try:
        # Access miRWalk website
        driver.get(MIRWALK_DOWNLOAD_PARAMETERS['base-url'])

        try:
            # Find and fill the species selector
            species_input = Select(driver.find_element(By.NAME, 'species'))
            species_input.select_by_visible_text(
                MIRWALK_DOWNLOAD_PARAMETERS['species-selection']
            )
        except NoSuchElementException:
            logging.error('Species selector not found.')
            return
        except ElementNotInteractableException:
            logging.error('Species selector not interactable')
            return

        try:
            # Find and fill the microRNA identifier
            mir_input = driver.find_element(By.NAME, 'mirna')
            mir_input.send_keys(accession_id)
        except NoSuchElementException:
            logging.error('MicroRNA identifier field not found')
            return
        except ElementNotInteractableException:
            logging.error('MicroRNA identifier field not interactable')
            return

        try:
            # Find and click the search button
            search_btn = driver.find_element(By.XPATH, '//button[text()="search"]')
            search_btn.click()
        except NoSuchElementException:
            logging.error('Search button not found')
            return
        except ElementNotInteractableException:
            logging.error('Search button not interactable')
            return

        try:
            # Find and click the export CSV button
            export_link = driver.find_element(By.LINK_TEXT, 'Export CSV')
            export_link.click()
        except NoSuchElementException:
            logging.error('Export CSV button not found')
            return
        except ElementNotInteractableException:
            logging.error('Export CSV button not interactable')
            return

        # Wait until the download is complete
        wait_time = 0
        while not os.path.exists(MIRWALK_DEFAULT_FILE_PATH):
            time.sleep(5)
            wait_time += 5
            if wait_time >= max_wait_time:
                logging.error('Download did not complete in the expected time')
                return

        try:
            # Change the name of the downloaded file
            mir_file_path = os.path.join(MIRWALK_EXTERNAL_DATA_DIR, f'{accession_id}.csv')
            os.rename(MIRWALK_DEFAULT_FILE_PATH, mir_file_path)
            logging.info(f'Downloaded and saved to {mir_file_path}')
        except OSError as e:
            logging.error(f'Error renaming the file: {e}')
            return

    except Exception as e:
        logging.exception(f'An unexpected error occurred: {e}')

# %%
def processing_mir_targets_file(file_name):
    """
    Process a microRNA target interactions file and flag interactions of interest.

    Parameters:
    -----------
    file_name : str 
        The name of the input CSV file located in the `MIRWALK_EXTERNAL_DATA_DIR` directory.

    Returns:
    --------
    str
        The complete name of the microRNA from the first record in the file.
    """
    # Create a DataFrame for the file
    df_interactions = pd.read_csv(f'{MIRWALK_EXTERNAL_DATA_DIR}/{file_name}')
    
    # Rename some DataFrame columns
    df_interactions = df_interactions \
        .rename(columns={
            'mirnaid': 'mirna_name',
            'refseqid': 'refseq_id',
            'genesymbol': 'gene_name',
            'validated': 'mirtarbase',
            'TargetScan': 'targetscan',
            'miRDB': 'mirdb',
        })
        
    # Get the microRNA complete name
    mir_name = df_interactions['mirna_name'][0]

    # Flag targets of interest, i.e. the microRNA-messenger RNA interactions
    # that occur in the 3UTR position and are predicted by TargetScan
    df_interactions['is_interaction_of_interest'] = np.where(
        ((df_interactions['position'] == '3UTR')
         & (df_interactions['targetscan'] == 1)), 1, 0
    )
    
    # Store the flagged targets file in a CSV file
    df_interactions.to_csv(f'{MIRWALK_PROCESSED_DATA_DIR}/{file_name}', index=False)
    
    return mir_name

# %% [markdown]
# # TCGA-BRCA Expressed MicroRNAs

# %%
# Initialize the set of expressed microRNAs in TCGA-BRCA
expressed_mirs = set()

# Prepare parameters for iterations
file_name = AGGREGATED_READS_FILES['mir-raw']
cohorts = list(BRCA_PROCESSED_FILES_DIRS.keys())
cohorts.remove('project')

# Get the microRNAs expressed in each cohort
for cohort in cohorts:
    # Set the path to the cohort's flagged expressed microRNAs file
    file_path = os.path.join(BRCA_PROCESSED_FILES_DIRS[cohort], file_name)
    
    # Create a set with the microRNAs expressed in the cohort
    df_expressed_mirs = pd.read_csv(file_path).query('is_expressed == 1')
    cohort_expressed_mirs = set(df_expressed_mirs['accession_id'].to_list())
    
    # Unite the sets of expressed microRNAs, general and cohort specific
    expressed_mirs = expressed_mirs.union(cohort_expressed_mirs)

# %%
# Print the total number of expressed microRNAs in TCGA-BRCA
print(f'Number of expressed microRNAs: {len(expressed_mirs)}')
# Out:
# Number of expressed microRNAs: 304

# %% [markdown]
# # miRWalk Data Download

# %%
# Create the Chrome WebDriver
driver = create_chrome_webdriver()

# Download the interactions file of each expressed microRNA
for accession_id in expressed_mirs:
    exporting_mir_targets_file(driver, accession_id)

# Close the Chrome WebDriver
driver.quit()
# Out:
# INFO:Downloading the interactions of microRNA MIMAT0003322...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003322.csv
# INFO:Downloading the interactions of microRNA MIMAT0004509...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004509.csv
# INFO:Downloading the interactions of microRNA MIMAT0000081...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000081.csv
# INFO:Downloading the interactions of microRNA MIMAT0004495...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004495.csv
# INFO:Downloading the interactions of microRNA MIMAT0026477...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0026477.csv
# INFO:Downloading the interactions of microRNA MIMAT0016888...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0016888.csv
# INFO:Downloading the interactions of microRNA MIMAT0004927...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004927.csv
# INFO:Downloading the interactions of microRNA MIMAT0004808...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004808.csv
# INFO:Downloading the interactions of microRNA MIMAT0000244...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000244.csv
# INFO:Downloading the interactions of microRNA MIMAT0004586...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004586.csv
# INFO:Downloading the interactions of microRNA MIMAT0004797...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004797.csv
# INFO:Downloading the interactions of microRNA MIMAT0003885...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003885.csv
# INFO:Downloading the interactions of microRNA MIMAT0000682...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000682.csv
# INFO:Downloading the interactions of microRNA MIMAT0000082...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000082.csv
# INFO:Downloading the interactions of microRNA MIMAT0000098...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000098.csv
# INFO:Downloading the interactions of microRNA MIMAT0000728...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000728.csv
# INFO:Downloading the interactions of microRNA MIMAT0000243...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000243.csv
# INFO:Downloading the interactions of microRNA MIMAT0000762...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000762.csv
# INFO:Downloading the interactions of microRNA MIMAT0000076...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000076.csv
# INFO:Downloading the interactions of microRNA MIMAT0000752...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000752.csv
# INFO:Downloading the interactions of microRNA MIMAT0004503...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004503.csv
# INFO:Downloading the interactions of microRNA MIMAT0003328...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003328.csv
# INFO:Downloading the interactions of microRNA MIMAT0000452...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000452.csv
# INFO:Downloading the interactions of microRNA MIMAT0000732...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000732.csv
# INFO:Downloading the interactions of microRNA MIMAT0000075...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000075.csv
# INFO:Downloading the interactions of microRNA MIMAT0002177...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002177.csv
# INFO:Downloading the interactions of microRNA MIMAT0000459...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000459.csv
# INFO:Downloading the interactions of microRNA MIMAT0019731...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0019731.csv
# INFO:Downloading the interactions of microRNA MIMAT0004604...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004604.csv
# INFO:Downloading the interactions of microRNA MIMAT0000727...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000727.csv
# INFO:Downloading the interactions of microRNA MIMAT0004564...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004564.csv
# INFO:Downloading the interactions of microRNA MIMAT0000088...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000088.csv
# INFO:Downloading the interactions of microRNA MIMAT0000103...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000103.csv
# INFO:Downloading the interactions of microRNA MIMAT0000750...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000750.csv
# INFO:Downloading the interactions of microRNA MIMAT0000764...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000764.csv
# INFO:Downloading the interactions of microRNA MIMAT0002871...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002871.csv
# INFO:Downloading the interactions of microRNA MIMAT0000258...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000258.csv
# INFO:Downloading the interactions of microRNA MIMAT0004559...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004559.csv
# INFO:Downloading the interactions of microRNA MIMAT0000063...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000063.csv
# INFO:Downloading the interactions of microRNA MIMAT0003879...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003879.csv
# INFO:Downloading the interactions of microRNA MIMAT0003393...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003393.csv
# INFO:Downloading the interactions of microRNA MIMAT0003242...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003242.csv
# INFO:Downloading the interactions of microRNA MIMAT0000087...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000087.csv
# INFO:Downloading the interactions of microRNA MIMAT0004688...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004688.csv
# INFO:Downloading the interactions of microRNA MIMAT0003886...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003886.csv
# INFO:Downloading the interactions of microRNA MIMAT0000267...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000267.csv
# INFO:Downloading the interactions of microRNA MIMAT0003258...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003258.csv
# INFO:Downloading the interactions of microRNA MIMAT0004485...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004485.csv
# INFO:Downloading the interactions of microRNA MIMAT0001341...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001341.csv
# INFO:Downloading the interactions of microRNA MIMAT0004494...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004494.csv
# INFO:Downloading the interactions of microRNA MIMAT0000222...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000222.csv
# INFO:Downloading the interactions of microRNA MIMAT0000680...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000680.csv
# INFO:Downloading the interactions of microRNA MIMAT0004501...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004501.csv
# INFO:Downloading the interactions of microRNA MIMAT0004601...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004601.csv
# INFO:Downloading the interactions of microRNA MIMAT0000077...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000077.csv
# INFO:Downloading the interactions of microRNA MIMAT0000097...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000097.csv
# INFO:Downloading the interactions of microRNA MIMAT0000757...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000757.csv
# INFO:Downloading the interactions of microRNA MIMAT0004672...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004672.csv
# INFO:Downloading the interactions of microRNA MIMAT0016847...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0016847.csv
# INFO:Downloading the interactions of microRNA MIMAT0000066...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000066.csv
# INFO:Downloading the interactions of microRNA MIMAT0000455...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000455.csv
# INFO:Downloading the interactions of microRNA MIMAT0002174...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002174.csv
# INFO:Downloading the interactions of microRNA MIMAT0000090...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000090.csv
# INFO:Downloading the interactions of microRNA MIMAT0005948...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0005948.csv
# INFO:Downloading the interactions of microRNA MIMAT0000274...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000274.csv
# INFO:Downloading the interactions of microRNA MIMAT0000264...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000264.csv
# INFO:Downloading the interactions of microRNA MIMAT0000263...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000263.csv
# INFO:Downloading the interactions of microRNA MIMAT0004597...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004597.csv
# INFO:Downloading the interactions of microRNA MIMAT0000443...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000443.csv
# INFO:Downloading the interactions of microRNA MIMAT0000250...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000250.csv
# INFO:Downloading the interactions of microRNA MIMAT0004657...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004657.csv
# INFO:Downloading the interactions of microRNA MIMAT0019761...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0019761.csv
# INFO:Downloading the interactions of microRNA MIMAT0004809...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004809.csv
# INFO:Downloading the interactions of microRNA MIMAT0004481...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004481.csv
# INFO:Downloading the interactions of microRNA MIMAT0000064...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000064.csv
# INFO:Downloading the interactions of microRNA MIMAT0000689...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000689.csv
# INFO:Downloading the interactions of microRNA MIMAT0000086...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000086.csv
# INFO:Downloading the interactions of microRNA MIMAT0000423...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000423.csv
# INFO:Downloading the interactions of microRNA MIMAT0000761...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000761.csv
# INFO:Downloading the interactions of microRNA MIMAT0004584...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004584.csv
# INFO:Downloading the interactions of microRNA MIMAT0004945...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004945.csv
# INFO:Downloading the interactions of microRNA MIMAT0000257...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000257.csv
# INFO:Downloading the interactions of microRNA MIMAT0004600...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004600.csv
# INFO:Downloading the interactions of microRNA MIMAT0000415...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000415.csv
# INFO:Downloading the interactions of microRNA MIMAT0004497...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004497.csv
# INFO:Downloading the interactions of microRNA MIMAT0000703...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000703.csv
# INFO:Downloading the interactions of microRNA MIMAT0000438...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000438.csv
# INFO:Downloading the interactions of microRNA MIMAT0002820...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002820.csv
# INFO:Downloading the interactions of microRNA MIMAT0004693...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004693.csv
# INFO:Downloading the interactions of microRNA MIMAT0000232...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000232.csv
# INFO:Downloading the interactions of microRNA MIMAT0004484...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004484.csv
# INFO:Downloading the interactions of microRNA MIMAT0004748...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004748.csv
# INFO:Downloading the interactions of microRNA MIMAT0004921...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004921.csv
# INFO:Downloading the interactions of microRNA MIMAT0000100...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000100.csv
# INFO:Downloading the interactions of microRNA MIMAT0005899...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0005899.csv
# INFO:Downloading the interactions of microRNA MIMAT0003298...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003298.csv
# INFO:Downloading the interactions of microRNA MIMAT0004550...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004550.csv
# INFO:Downloading the interactions of microRNA MIMAT0002888...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002888.csv
# INFO:Downloading the interactions of microRNA MIMAT0001638...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001638.csv
# INFO:Downloading the interactions of microRNA MIMAT0000281...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000281.csv
# INFO:Downloading the interactions of microRNA MIMAT0000255...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000255.csv
# INFO:Downloading the interactions of microRNA MIMAT0000079...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000079.csv
# INFO:Downloading the interactions of microRNA MIMAT0000091...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000091.csv
# INFO:Downloading the interactions of microRNA MIMAT0000271...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000271.csv
# INFO:Downloading the interactions of microRNA MIMAT0000437...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000437.csv
# INFO:Downloading the interactions of microRNA MIMAT0004703...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004703.csv
# INFO:Downloading the interactions of microRNA MIMAT0004799...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004799.csv
# INFO:Downloading the interactions of microRNA MIMAT0000275...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000275.csv
# INFO:Downloading the interactions of microRNA MIMAT0002874...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002874.csv
# INFO:Downloading the interactions of microRNA MIMAT0002819...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002819.csv
# INFO:Downloading the interactions of microRNA MIMAT0006789...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0006789.csv
# INFO:Downloading the interactions of microRNA MIMAT0000073...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000073.csv
# INFO:Downloading the interactions of microRNA MIMAT0002809...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002809.csv
# INFO:Downloading the interactions of microRNA MIMAT0000688...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000688.csv
# INFO:Downloading the interactions of microRNA MIMAT0004814...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004814.csv
# INFO:Downloading the interactions of microRNA MIMAT0000254...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000254.csv
# INFO:Downloading the interactions of microRNA MIMAT0000760...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000760.csv
# INFO:Downloading the interactions of microRNA MIMAT0004784...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004784.csv
# INFO:Downloading the interactions of microRNA MIMAT0004558...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004558.csv
# INFO:Downloading the interactions of microRNA MIMAT0000420...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000420.csv
# INFO:Downloading the interactions of microRNA MIMAT0000445...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000445.csv
# INFO:Downloading the interactions of microRNA MIMAT0001536...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001536.csv
# INFO:Downloading the interactions of microRNA MIMAT0000433...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000433.csv
# INFO:Downloading the interactions of microRNA MIMAT0000266...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000266.csv
# INFO:Downloading the interactions of microRNA MIMAT0000646...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000646.csv
# INFO:Downloading the interactions of microRNA MIMAT0000448...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000448.csv
# INFO:Downloading the interactions of microRNA MIMAT0004606...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004606.csv
# INFO:Downloading the interactions of microRNA MIMAT0004515...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004515.csv
# INFO:Downloading the interactions of microRNA MIMAT0022692...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0022692.csv
# INFO:Downloading the interactions of microRNA MIMAT0001080...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001080.csv
# INFO:Downloading the interactions of microRNA MIMAT0000072...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000072.csv
# INFO:Downloading the interactions of microRNA MIMAT0000419...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000419.csv
# INFO:Downloading the interactions of microRNA MIMAT0000083...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000083.csv
# INFO:Downloading the interactions of microRNA MIMAT0004598...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004598.csv
# INFO:Downloading the interactions of microRNA MIMAT0004766...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004766.csv
# INFO:Downloading the interactions of microRNA MIMAT0022721...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0022721.csv
# INFO:Downloading the interactions of microRNA MIMAT0000447...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000447.csv
# INFO:Downloading the interactions of microRNA MIMAT0000099...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000099.csv
# INFO:Downloading the interactions of microRNA MIMAT0004909...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004909.csv
# INFO:Downloading the interactions of microRNA MIMAT0000731...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000731.csv
# INFO:Downloading the interactions of microRNA MIMAT0000710...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000710.csv
# INFO:Downloading the interactions of microRNA MIMAT0000705...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000705.csv
# INFO:Downloading the interactions of microRNA MIMAT0006790...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0006790.csv
# INFO:Downloading the interactions of microRNA MIMAT0000460...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000460.csv
# INFO:Downloading the interactions of microRNA MIMAT0000261...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000261.csv
# INFO:Downloading the interactions of microRNA MIMAT0000279...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000279.csv
# INFO:Downloading the interactions of microRNA MIMAT0004502...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004502.csv
# INFO:Downloading the interactions of microRNA MIMAT0000084...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000084.csv
# INFO:Downloading the interactions of microRNA MIMAT0004673...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004673.csv
# INFO:Downloading the interactions of microRNA MIMAT0022472...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0022472.csv
# INFO:Downloading the interactions of microRNA MIMAT0000692...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000692.csv
# INFO:Downloading the interactions of microRNA MIMAT0022696...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0022696.csv
# INFO:Downloading the interactions of microRNA MIMAT0000253...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000253.csv
# INFO:Downloading the interactions of microRNA MIMAT0000426...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000426.csv
# INFO:Downloading the interactions of microRNA MIMAT0005797...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0005797.csv
# INFO:Downloading the interactions of microRNA MIMAT0004518...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004518.csv
# INFO:Downloading the interactions of microRNA MIMAT0003266...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003266.csv
# INFO:Downloading the interactions of microRNA MIMAT0004929...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004929.csv
# INFO:Downloading the interactions of microRNA MIMAT0000262...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000262.csv
# INFO:Downloading the interactions of microRNA MIMAT0004694...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004694.csv
# INFO:Downloading the interactions of microRNA MIMAT0004757...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004757.csv
# INFO:Downloading the interactions of microRNA MIMAT0000265...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000265.csv
# INFO:Downloading the interactions of microRNA MIMAT0002817...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002817.csv
# INFO:Downloading the interactions of microRNA MIMAT0001635...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001635.csv
# INFO:Downloading the interactions of microRNA MIMAT0004680...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004680.csv
# INFO:Downloading the interactions of microRNA MIMAT0000434...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000434.csv
# INFO:Downloading the interactions of microRNA MIMAT0000722...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000722.csv
# INFO:Downloading the interactions of microRNA MIMAT0004614...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004614.csv
# INFO:Downloading the interactions of microRNA MIMAT0000510...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000510.csv
# INFO:Downloading the interactions of microRNA MIMAT0004571...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004571.csv
# INFO:Downloading the interactions of microRNA MIMAT0003249...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003249.csv
# INFO:Downloading the interactions of microRNA MIMAT0004682...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004682.csv
# INFO:Downloading the interactions of microRNA MIMAT0003389...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003389.csv
# INFO:Downloading the interactions of microRNA MIMAT0000450...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000450.csv
# INFO:Downloading the interactions of microRNA MIMAT0022726...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0022726.csv
# INFO:Downloading the interactions of microRNA MIMAT0000245...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000245.csv
# INFO:Downloading the interactions of microRNA MIMAT0005949...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0005949.csv
# INFO:Downloading the interactions of microRNA MIMAT0000280...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000280.csv
# INFO:Downloading the interactions of microRNA MIMAT0000432...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000432.csv
# INFO:Downloading the interactions of microRNA MIMAT0004482...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004482.csv
# INFO:Downloading the interactions of microRNA MIMAT0000062...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000062.csv
# INFO:Downloading the interactions of microRNA MIMAT0000418...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000418.csv
# INFO:Downloading the interactions of microRNA MIMAT0004549...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004549.csv
# INFO:Downloading the interactions of microRNA MIMAT0004603...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004603.csv
# INFO:Downloading the interactions of microRNA MIMAT0000754...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000754.csv
# INFO:Downloading the interactions of microRNA MIMAT0000753...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000753.csv
# INFO:Downloading the interactions of microRNA MIMAT0005794...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0005794.csv
# INFO:Downloading the interactions of microRNA MIMAT0000074...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000074.csv
# INFO:Downloading the interactions of microRNA MIMAT0000231...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000231.csv
# INFO:Downloading the interactions of microRNA MIMAT0000441...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000441.csv
# INFO:Downloading the interactions of microRNA MIMAT0000065...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000065.csv
# INFO:Downloading the interactions of microRNA MIMAT0000092...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000092.csv
# INFO:Downloading the interactions of microRNA MIMAT0000446...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000446.csv
# INFO:Downloading the interactions of microRNA MIMAT0005878...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0005878.csv
# INFO:Downloading the interactions of microRNA MIMAT0000424...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000424.csv
# INFO:Downloading the interactions of microRNA MIMAT0000691...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000691.csv
# INFO:Downloading the interactions of microRNA MIMAT0022834...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0022834.csv
# INFO:Downloading the interactions of microRNA MIMAT0003218...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003218.csv
# INFO:Downloading the interactions of microRNA MIMAT0000435...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000435.csv
# INFO:Downloading the interactions of microRNA MIMAT0004553...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004553.csv
# INFO:Downloading the interactions of microRNA MIMAT0004775...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004775.csv
# INFO:Downloading the interactions of microRNA MIMAT0000416...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000416.csv
# INFO:Downloading the interactions of microRNA MIMAT0018101...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0018101.csv
# INFO:Downloading the interactions of microRNA MIMAT0000226...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000226.csv
# INFO:Downloading the interactions of microRNA MIMAT0004780...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004780.csv
# INFO:Downloading the interactions of microRNA MIMAT0000756...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000756.csv
# INFO:Downloading the interactions of microRNA MIMAT0017985...
# ERROR:Export CSV button not found
# INFO:Downloading the interactions of microRNA MIMAT0004615...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004615.csv
# INFO:Downloading the interactions of microRNA MIMAT0000259...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000259.csv
# INFO:Downloading the interactions of microRNA MIMAT0000737...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000737.csv
# INFO:Downloading the interactions of microRNA MIMAT0019208...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0019208.csv
# INFO:Downloading the interactions of microRNA MIMAT0003239...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003239.csv
# INFO:Downloading the interactions of microRNA MIMAT0004946...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004946.csv
# INFO:Downloading the interactions of microRNA MIMAT0000440...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000440.csv
# INFO:Downloading the interactions of microRNA MIMAT0022727...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0022727.csv
# INFO:Downloading the interactions of microRNA MIMAT0010195...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0010195.csv
# INFO:Downloading the interactions of microRNA MIMAT0000449...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000449.csv
# INFO:Downloading the interactions of microRNA MIMAT0002876...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002876.csv
# INFO:Downloading the interactions of microRNA MIMAT0000461...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000461.csv
# INFO:Downloading the interactions of microRNA MIMAT0026472...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0026472.csv
# INFO:Downloading the interactions of microRNA MIMAT0003283...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003283.csv
# INFO:Downloading the interactions of microRNA MIMAT0004513...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004513.csv
# INFO:Downloading the interactions of microRNA MIMAT0000104...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000104.csv
# INFO:Downloading the interactions of microRNA MIMAT0000451...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000451.csv
# INFO:Downloading the interactions of microRNA MIMAT0004552...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004552.csv
# INFO:Downloading the interactions of microRNA MIMAT0004776...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004776.csv
# INFO:Downloading the interactions of microRNA MIMAT0019814...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0019814.csv
# INFO:Downloading the interactions of microRNA MIMAT0000080...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000080.csv
# INFO:Downloading the interactions of microRNA MIMAT0000431...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000431.csv
# INFO:Downloading the interactions of microRNA MIMAT0001639...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001639.csv
# INFO:Downloading the interactions of microRNA MIMAT0004599...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004599.csv
# INFO:Downloading the interactions of microRNA MIMAT0001620...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001620.csv
# INFO:Downloading the interactions of microRNA MIMAT0002171...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002171.csv
# INFO:Downloading the interactions of microRNA MIMAT0004926...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004926.csv
# INFO:Downloading the interactions of microRNA MIMAT0004493...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004493.csv
# INFO:Downloading the interactions of microRNA MIMAT0000681...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000681.csv
# INFO:Downloading the interactions of microRNA MIMAT0000096...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000096.csv
# INFO:Downloading the interactions of microRNA MIMAT0001343...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001343.csv
# INFO:Downloading the interactions of microRNA MIMAT0000456...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000456.csv
# INFO:Downloading the interactions of microRNA MIMAT0003163...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003163.csv
# INFO:Downloading the interactions of microRNA MIMAT0000070...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000070.csv
# INFO:Downloading the interactions of microRNA MIMAT0017990...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0017990.csv
# INFO:Downloading the interactions of microRNA MIMAT0000095...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000095.csv
# INFO:Downloading the interactions of microRNA MIMAT0000444...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000444.csv
# INFO:Downloading the interactions of microRNA MIMAT0003150...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003150.csv
# INFO:Downloading the interactions of microRNA MIMAT0001340...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001340.csv
# INFO:Downloading the interactions of microRNA MIMAT0015378...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0015378.csv
# INFO:Downloading the interactions of microRNA MIMAT0000693...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000693.csv
# INFO:Downloading the interactions of microRNA MIMAT0004955...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004955.csv
# INFO:Downloading the interactions of microRNA MIMAT0005920...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0005920.csv
# INFO:Downloading the interactions of microRNA MIMAT0000772...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000772.csv
# INFO:Downloading the interactions of microRNA MIMAT0004692...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004692.csv
# INFO:Downloading the interactions of microRNA MIMAT0000318...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000318.csv
# INFO:Downloading the interactions of microRNA MIMAT0002808...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002808.csv
# INFO:Downloading the interactions of microRNA MIMAT0000078...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000078.csv
# INFO:Downloading the interactions of microRNA MIMAT0000759...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000759.csv
# INFO:Downloading the interactions of microRNA MIMAT0002821...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002821.csv
# INFO:Downloading the interactions of microRNA MIMAT0004911...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004911.csv
# INFO:Downloading the interactions of microRNA MIMAT0004588...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004588.csv
# INFO:Downloading the interactions of microRNA MIMAT0000069...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000069.csv
# INFO:Downloading the interactions of microRNA MIMAT0000414...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000414.csv
# INFO:Downloading the interactions of microRNA MIMAT0000758...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000758.csv
# INFO:Downloading the interactions of microRNA MIMAT0026738...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0026738.csv
# INFO:Downloading the interactions of microRNA MIMAT0016895...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0016895.csv
# INFO:Downloading the interactions of microRNA MIMAT0000278...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000278.csv
# INFO:Downloading the interactions of microRNA MIMAT0000272...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000272.csv
# INFO:Downloading the interactions of microRNA MIMAT0000256...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000256.csv
# INFO:Downloading the interactions of microRNA MIMAT0000617...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000617.csv
# INFO:Downloading the interactions of microRNA MIMAT0001413...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001413.csv
# INFO:Downloading the interactions of microRNA MIMAT0000763...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000763.csv
# INFO:Downloading the interactions of microRNA MIMAT0000733...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000733.csv
# INFO:Downloading the interactions of microRNA MIMAT0003329...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003329.csv
# INFO:Downloading the interactions of microRNA MIMAT0000071...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000071.csv
# INFO:Downloading the interactions of microRNA MIMAT0004585...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004585.csv
# INFO:Downloading the interactions of microRNA MIMAT0000765...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000765.csv
# INFO:Downloading the interactions of microRNA MIMAT0004697...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004697.csv
# INFO:Downloading the interactions of microRNA MIMAT0002814...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0002814.csv
# INFO:Downloading the interactions of microRNA MIMAT0025477...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0025477.csv
# INFO:Downloading the interactions of microRNA MIMAT0000270...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000270.csv
# INFO:Downloading the interactions of microRNA MIMAT0000093...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000093.csv
# INFO:Downloading the interactions of microRNA MIMAT0004810...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004810.csv
# INFO:Downloading the interactions of microRNA MIMAT0003241...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003241.csv
# INFO:Downloading the interactions of microRNA MIMAT0004563...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004563.csv
# INFO:Downloading the interactions of microRNA MIMAT0004678...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004678.csv
# INFO:Downloading the interactions of microRNA MIMAT0000425...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000425.csv
# INFO:Downloading the interactions of microRNA MIMAT0004702...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004702.csv
# INFO:Downloading the interactions of microRNA MIMAT0000101...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000101.csv
# INFO:Downloading the interactions of microRNA MIMAT0000068...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000068.csv
# INFO:Downloading the interactions of microRNA MIMAT0000085...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000085.csv
# INFO:Downloading the interactions of microRNA MIMAT0004774...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004774.csv
# INFO:Downloading the interactions of microRNA MIMAT0022929...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0022929.csv
# INFO:Downloading the interactions of microRNA MIMAT0000067...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000067.csv
# INFO:Downloading the interactions of microRNA MIMAT0001631...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001631.csv
# INFO:Downloading the interactions of microRNA MIMAT0005951...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0005951.csv
# INFO:Downloading the interactions of microRNA MIMAT0003338...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0003338.csv
# INFO:Downloading the interactions of microRNA MIMAT0004500...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004500.csv
# INFO:Downloading the interactions of microRNA MIMAT0000417...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000417.csv
# INFO:Downloading the interactions of microRNA MIMAT0000736...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000736.csv
# INFO:Downloading the interactions of microRNA MIMAT0004556...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004556.csv
# INFO:Downloading the interactions of microRNA MIMAT0009451...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0009451.csv
# INFO:Downloading the interactions of microRNA MIMAT0001621...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0001621.csv
# INFO:Downloading the interactions of microRNA MIMAT0026480...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0026480.csv
# INFO:Downloading the interactions of microRNA MIMAT0000227...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0000227.csv
# INFO:Downloading the interactions of microRNA MIMAT0004511...
# INFO:Downloaded and saved to /home/my-roberta/Unicamp/pan-cancer-analysis/data/external/mirwalk/MIMAT0004511.csv

# %% [markdown]
# # miRWalk Data Processing

# %%
# Initialize a dictionary to map accession IDs to microRNA names
mir_mapping = dict.fromkeys(list(expressed_mirs))

# List the interaction files downloaded from miRWalk
files = [f for f in os.listdir(MIRWALK_EXTERNAL_DATA_DIR)]

# Process the interaction files individually
for file in files:
    # Process the file and get the microRNA name
    mir_name = processing_mir_targets_file(file)
    
    # Map the accession ID to the microRNA name
    accession_id = file.replace('.csv', '')
    mir_mapping[accession_id] = mir_name

# Create a DataFrame of the microRNA-related mapping
df_mir_mapping = pd.DataFrame.from_dict(data=mir_mapping, orient='index')
df_mir_mapping.reset_index(inplace=True)
df_mir_mapping.columns = ['accession_id', 'mirna_name']

# Store the DataFrame of the microRNA-related mapping in a CSV file
df_mir_mapping.to_csv(MIRWALK_MIR_MAPPING_FILE_PATH, index=False)
# Out:
# /tmp/ipykernel_12447/142047883.py:16: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_interactions = pd.read_csv(f'{MIRWALK_EXTERNAL_DATA_DIR}/{file_name}')

# %%
# Print the DataFrame of the microRNA-related mapping
df_mir_mapping
# Out:
#      accession_id        mirna_name
# 0    MIMAT0003322    hsa-miR-652-3p
# 1    MIMAT0004509     hsa-miR-93-3p
# 2    MIMAT0000081     hsa-miR-25-3p
# 3    MIMAT0004495     hsa-miR-22-5p
# 4    MIMAT0026477  hsa-miR-128-1-5p
# ..            ...               ...
# 299  MIMAT0009451      hsa-miR-1976
# 300  MIMAT0001621    hsa-miR-369-5p
# 301  MIMAT0026480    hsa-miR-153-5p
# 302  MIMAT0000227    hsa-miR-197-3p
# 303  MIMAT0004511    hsa-miR-99a-3p
#
# [304 rows x 2 columns]
