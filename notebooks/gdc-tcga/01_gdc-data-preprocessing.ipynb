# %% [markdown]
# # **Preprocessing GDC API Data**
# GDC: Genomic Data Commons

# %% [markdown]
# # Importing Libraries

# %%
import json

import pandas as pd
import requests

# %% [markdown]
# # Constants and Path

# %%
# Base URL HTML from GDC API
GDC_API_URL = 'https://api.gdc.cancer.gov'

# Endpoint to get API status and version
STATUS_ENDPOINT = f'{GDC_API_URL}/status'

# Endpoint of projects related to programs
PROJECTS_ENDPOINT = f'{GDC_API_URL}/projects'

# Endpoint of cases related to projects
CASES_ENDPOINT = f'{GDC_API_URL}/cases'

# Endpoint of files related to cases
FILES_ENDPOINT = f'{GDC_API_URL}/files'

# Interim data folder path
INTERIM_DATA_PATH = '../../data/interim/gdc-tcga'

# %% [markdown]
# # API Status

# %%
# Request the API version and status to the endpoint
response = requests.get(STATUS_ENDPOINT)

# Print the response content
print(response.content.decode('utf-8'))
# Out:
# {"commit":"48add4be7ac46e7db10e0c6f0e3010d5bb2a50aa","data_release":"Data Release 42.0 - January 30, 2025","data_release_version":{"major":42,"minor":0,"release_date":"2025-01-30"},"status":"OK","tag":"7.7","version":1}

# %% [markdown]
# # Projects

# %% [markdown]
# ## All Projects
# Total projects contained in the GDC API

# %%
# Request the information contained in the endpoint
response = requests.get(f'{PROJECTS_ENDPOINT}/_mapping')

# Convert the response content to JSON
json_response = json.loads(response.content.decode('utf-8'))

# Store the fields available in the endpoint
fields_projects = json.dumps(json_response['fields'])[1:-2]
fields_projects = fields_projects.replace('"', '')
fields_projects = fields_projects.replace(' ', '')

# %%
# Request the default number of objects to the endpoint
response = requests.post(
    url=PROJECTS_ENDPOINT,
    headers={'Content-Type': 'application/json'},
    json={'fields': 'name'}
)

# Convert the response content to JSON
json_response = json.loads(response.content.decode('utf-8'))

# Store the total number of projects contained in the GDC API
total_projects = json.dumps(json_response['data']['pagination']['total'])
print(f'Total number of projects: {total_projects}')
# Out:
# Total number of projects: 86

# %%
# Parameters for the endpoint request
params = {
    'fields': fields_projects,
    'size': total_projects
}

# Request all objects from the endpoint
response = requests.post(
    url=PROJECTS_ENDPOINT,
    headers={'Content-Type': 'application/json'},
    json=params
)

# Convert the response content to JSON
json_response = json.loads(response.content.decode('utf-8'))['data']['hits']

# Convert JSON boolean values to strings
for index in range(len(json_response)):
    obj = json_response[index]
    for key in obj:
        if isinstance(obj[key], bool): 
            obj[key] = str(obj[key])

# Create a DataFrame from the projects JSON
df_all_projects = pd.json_normalize(json_response) \
    .sort_values(by='id') \
    .reset_index(drop=True)

# %%
# Write the DataFrame in a CSV file
file_name = 'gdc-projects.csv'
df_all_projects.to_csv(f'{INTERIM_DATA_PATH}/{file_name}', index=False)

# Print the DataFrame partially
pd.set_option('display.max_colwidth', 100)
df_all_projects.head(3)
# Out:
#                       id                                     primary_site  \
# 0            APOLLO-LUAD                              [Bronchus and lung]
# 1      BEATAML1.0-COHORT  [Hematopoietic and reticuloendothelial systems]
# 2  BEATAML1.0-CRENOLANIB  [Hematopoietic and reticuloendothelial systems]
#
#   dbgap_accession_number             project_id  \
# 0              phs003011            APOLLO-LUAD
# 1              phs001657      BEATAML1.0-COHORT
# 2              phs001628  BEATAML1.0-CRENOLANIB
#
#                                                                                           disease_type  \
# 0                                                                       [Adenomas and Adenocarcinomas]
# 1  [Plasma Cell Tumors, Myelodysplastic Syndromes, Unknown, Chronic Myeloproliferative Disorders, M...
# 2                                                                                  [Myeloid Leukemias]
#
#                                                                                               name  \
# 0                                   APOLLO1: Proteogenomic characterization of lung adenocarcinoma
# 1                                           Functional Genomic Landscape of Acute Myeloid Leukemia
# 2  Clinical Resistance to Crenolanib in Acute Myeloid Leukemia Due to Diverse Molecular Mechanisms
#
#   releasable state released  summary.file_count  \
# 0      False  open     True                1679
# 1       True  open     True               16794
# 2      False  open     True                 547
#
#                                                                                summary.data_categories  \
# 0  [{'file_count': 435, 'case_count': 87, 'data_category': 'Sequencing Reads'}, {'file_count': 194,...
# 1  [{'file_count': 8777, 'case_count': 759, 'data_category': 'Simple Nucleotide Variation'}, {'file...
# 2  [{'file_count': 428, 'case_count': 51, 'data_category': 'Simple Nucleotide Variation'}, {'file_c...
#
#                                                                        summary.experimental_strategies  \
# 0  [{'file_count': 783, 'case_count': 87, 'experimental_strategy': 'RNA-Seq'}, {'file_count': 896, ...
# 1  [{'file_count': 7478, 'case_count': 534, 'experimental_strategy': 'WXS'}, {'file_count': 2653, '...
# 2                              [{'file_count': 547, 'case_count': 56, 'experimental_strategy': 'WXS'}]
#
#    summary.case_count  summary.file_size program.dbgap_accession_number  \
# 0                  87     67389870223275                           None
# 1                 826     42355372208215                           None
# 2                  56      3608907348655                           None
#
#                      program.program_id program.name
# 0  bd5bea9d-29ff-52e4-92f5-463837c6f6cf       APOLLO
# 1  1eaac0a3-91f6-54b3-9a7c-e34468eaf527   BEATAML1.0
# 2  1eaac0a3-91f6-54b3-9a7c-e34468eaf527   BEATAML1.0

# %% [markdown]
# ## Projects of Interest
# Projects Released with miRNA-Seq and RNA-Seq

# %%
# Filter released projects and drop unnecessary columns
df_projects = df_all_projects \
    .query('released == "True"') \
    .drop(
        columns=[
            'dbgap_accession_number',
            'id',
            'releasable',
            'released',
            'program.dbgap_accession_number',
            'program.name',
            'program.program_id',
            'state',
            'summary.data_categories',
            'summary.file_count',
            'summary.file_size'
        ]
    )

# Initialize lists for counting cases with miRNA-Seq and RNA-Seq in projects
miRNA_Seq_case_count = [0] * df_projects.shape[0]
RNA_Seq_case_count = [0] * df_projects.shape[0]

# Fill the lists with counts of cases with miRNA-Seq and RNA-Seq in each project
for index in range(df_projects.shape[0]):
    for info in df_projects['summary.experimental_strategies'][index]:
        if info['experimental_strategy'] in ['miRNA-Seq', 'RNA-Seq']:
            if info['experimental_strategy'] == 'miRNA-Seq':
                miRNA_Seq_case_count[index] = info['case_count']
            else:
                RNA_Seq_case_count[index] = info['case_count']

# Add the count of cases with miRNA-Seq and RNA-Seq to the DataFrame
df_projects['miRNA-Seq_case_count'] = miRNA_Seq_case_count
df_projects['RNA-Seq_case_count'] = RNA_Seq_case_count

# Filter projects with miRNA-Seq and RNA-Seq as experimental strategy
df_projects = df_projects \
    .query('(`miRNA-Seq_case_count` > 0) & (`RNA-Seq_case_count` > 0)') \
    .drop(columns='summary.experimental_strategies') \
    .reset_index(drop=True)

# Rearrange and rename the DataFrame columns
columns = [
    'project_id',
    'name',
    'primary_site',
    'disease_type',
    'summary.case_count',
    'miRNA-Seq_case_count',
    'RNA-Seq_case_count'
]
df_projects = df_projects[columns] \
    .rename(
        columns={
            'name': 'project_name',
            'summary.case_count': 'case_count',
        }
    )

# Print the total number of projects with the desired characteristics
print(f'Total number of projects of interest: {df_projects.shape[0]}')
# Out:
# Total number of projects of interest: 47

# %%
# Write the DataFrame in a CSV file
file_name = 'gdc-projects-of-interest.csv'
df_projects.to_csv(f'{INTERIM_DATA_PATH}/{file_name}', index=False)

# Print the DataFrame partially
pd.set_option('display.max_colwidth', 100)
df_projects.head(3)
# Out:
#          project_id  \
# 0        CGCI-BLGSP
# 1     CGCI-HTMCP-CC
# 2  CGCI-HTMCP-DLBCL
#
#                                                                     project_name  \
# 0                                     Burkitt Lymphoma Genome Sequencing Project
# 1                HIV+ Tumor Molecular Characterization Project - Cervical Cancer
# 2  HIV+ Tumor Molecular Characterization Project - Diffuse Large B-Cell Lymphoma
#
#                                       primary_site  \
# 0  [Hematopoietic and reticuloendothelial systems]
# 1                                   [Cervix uteri]
# 2  [Hematopoietic and reticuloendothelial systems]
#
#                                                                                           disease_type  \
# 0                                                                            [Mature B-Cell Lymphomas]
# 1  [Adenomas and Adenocarcinomas, Squamous Cell Neoplasms, Epithelial Neoplasms, NOS, Complex Epith...
# 2                                                                            [Mature B-Cell Lymphomas]
#
#    case_count  miRNA-Seq_case_count  RNA-Seq_case_count
# 0         324                   278                 283
# 1         212                   118                 123
# 2          70                    60                  55

# %% [markdown]
# # Cases and Files

# %% [markdown]
# ## Cases of Interest
# Cases with miRNA-Seq and RNA-Seq

# %%
# Fields of interest for the endpoint request
fields = [
    'disease_type',
    'files.access',
    'files.data_category',
    'files.data_format',
    'files.data_type',
    'files.file_id',
    'files.experimental_strategy',
    'primary_site',
    'project.project_id'
]
fields = ','.join(fields)

# Initialize the DataFrame of cases and files
df_cases_and_files = pd.DataFrame()

# Search for cases with miRNA-Seq and RNA-Seq in each project of interest
for index in range(df_projects.shape[0]):
    # Filters used in the endpoint request
    filters = {
        'op': 'and',
        'content': [
            {
                'op': '=',
                'content': {
                    'field': 'project.project_id',
                    'value': df_projects['project_id'][index]
                }
            },
            {
                'op': 'in',
                'content': {
                    'field': 'files.experimental_strategy',
                    'value': ['miRNA-Seq', 'RNA-Seq']
                }
            }
        ]
    }

    # Parameters for the endpoint request
    params = {
        'fields': fields,
        'filters': filters,
        'size': str(df_projects['case_count'][index])
    }

    # Request all project objects to the endpoint
    response = requests.post(
        url=CASES_ENDPOINT,
        headers={'Content-Type': 'application/json'},
        json=params
    )

    # Transform the response content to a DataFrame
    json_response = json.loads(response.content.decode('utf-8'))
    df_project_cases = pd.json_normalize(json_response['data']['hits'])

    # Concatenate the cases of this project with the others
    if df_cases_and_files.empty == False:
        df_cases_and_files = pd.concat(
            [df_cases_and_files, df_project_cases], ignore_index=True
        )
    else:
        df_cases_and_files = df_project_cases.copy()

# Rename some columns of the DataFrame
df_cases_and_files = df_cases_and_files.rename(
    columns={'id': 'case_id', 'project.project_id': 'project_id'}
)

# %%
# Create the cases DataFrame
df_cases = df_cases_and_files.drop(columns='files')

# Write the DataFrame in a CSV file
file_name = 'gdc-cases-of-interest.csv'
df_cases.to_csv(f'{INTERIM_DATA_PATH}/{file_name}', index=False)

# Print the DataFrame
df_cases
# Out:
#                                     case_id  \
# 0      cbb553da-c61c-4734-ac58-ef4580aaef47
# 1      681ff2e8-6073-4dab-a398-1f2203c2d7f5
# 2      886e1609-e89c-4d5e-ab9d-4f9ae18c937a
# 3      fdc9dadf-33c7-4b64-8bad-d6bb56fb2209
# 4      edf2e5ba-5702-4f96-97f7-124d70bb16aa
# ...                                     ...
# 16785  e21d8018-8fe9-4c92-8b36-28d7d3f7df2b
# 16786  ebdabfcb-1c68-4ca1-8b7f-3ea9cdac3a6a
# 16787  edbf6720-467e-4928-b1cb-0e7336358d18
# 16788  eeab0529-31e6-4edb-bd2c-a21f2a169381
# 16789  f78d8541-b317-4c8a-aa66-f172a8eaf14f
#
#                                         primary_site             disease_type  \
# 0      Hematopoietic and reticuloendothelial systems  Mature B-Cell Lymphomas
# 1      Hematopoietic and reticuloendothelial systems  Mature B-Cell Lymphomas
# 2      Hematopoietic and reticuloendothelial systems  Mature B-Cell Lymphomas
# 3      Hematopoietic and reticuloendothelial systems  Mature B-Cell Lymphomas
# 4      Hematopoietic and reticuloendothelial systems  Mature B-Cell Lymphomas
# ...                                              ...                      ...
# 16785                                 Eye and adnexa       Nevi and Melanomas
# 16786                                 Eye and adnexa       Nevi and Melanomas
# 16787                                 Eye and adnexa       Nevi and Melanomas
# 16788                                 Eye and adnexa       Nevi and Melanomas
# 16789                                 Eye and adnexa       Nevi and Melanomas
#
#        project_id
# 0      CGCI-BLGSP
# 1      CGCI-BLGSP
# 2      CGCI-BLGSP
# 3      CGCI-BLGSP
# 4      CGCI-BLGSP
# ...           ...
# 16785    TCGA-UVM
# 16786    TCGA-UVM
# 16787    TCGA-UVM
# 16788    TCGA-UVM
# 16789    TCGA-UVM
#
# [16790 rows x 4 columns]

# %% [markdown]
# ## Files of Interest
# Files from miRNA-Seq and RNA-Seq

# %%
# Explode the lists dictionary over case files
df_cases_and_files = df_cases_and_files.explode('files')

# Filter case files related to miRNA-Seq or RNA-Seq
key = 'experimental_strategy'
df_cases_and_files = df_cases_and_files[
    df_cases_and_files['files'].apply(
        lambda x: (
            key in x and (x[key] == 'miRNA-Seq' or x[key] == 'RNA-Seq')
        )
    )
]

# Create the files DataFrame
df_files = pd.concat(
    objs=[
        df_cases_and_files.reset_index(drop=True),
        pd.json_normalize(df_cases_and_files['files'])
    ],
    axis='columns'
)
df_files = df_files.drop(
    columns=['disease_type', 'files', 'primary_site', 'project_id']
)

# %%
# Write the DataFrame in a CSV file
file_name = 'gdc-files-of-interest.csv'
df_files.to_csv(f'{INTERIM_DATA_PATH}/{file_name}', index=False)

# Print the DataFrame
df_files
# Out:
#                                      case_id data_format      access  \
# 0       cbb553da-c61c-4734-ac58-ef4580aaef47         TSV  controlled
# 1       cbb553da-c61c-4734-ac58-ef4580aaef47         TSV        open
# 2       cbb553da-c61c-4734-ac58-ef4580aaef47         TSV  controlled
# 3       cbb553da-c61c-4734-ac58-ef4580aaef47         TSV  controlled
# 4       cbb553da-c61c-4734-ac58-ef4580aaef47       BEDPE  controlled
# ...                                      ...         ...         ...
# 232548  f78d8541-b317-4c8a-aa66-f172a8eaf14f       BEDPE  controlled
# 232549  f78d8541-b317-4c8a-aa66-f172a8eaf14f         TSV  controlled
# 232550  f78d8541-b317-4c8a-aa66-f172a8eaf14f         BAM  controlled
# 232551  f78d8541-b317-4c8a-aa66-f172a8eaf14f         TSV        open
# 232552  f78d8541-b317-4c8a-aa66-f172a8eaf14f         TXT        open
#
#                                      file_id                        data_type  \
# 0       7fad3cc2-cc77-4f0f-b63c-a94a274f10e2                Transcript Fusion
# 1       030842d9-69b2-4938-9475-31c43cce6f7a   Gene Expression Quantification
# 2       862a63ae-d83e-431d-94fb-613570e01477   Splice Junction Quantification
# 3       44816e46-1474-4c6c-a4c8-c2cee21329d0                Transcript Fusion
# 4       a93709d9-9a6f-4ceb-aeca-a9afd48c13b1                Transcript Fusion
# ...                                      ...                              ...
# 232548  8a7a812c-cb90-492a-982f-f27e3ce39794                Transcript Fusion
# 232549  c948d42f-8eb8-4425-b8dd-27b973ccc6b7   Splice Junction Quantification
# 232550  c5a9c2d9-1971-4eaf-923e-f2d1df90fdcb                    Aligned Reads
# 232551  e1849623-895a-4981-b8c1-25ad0ec1143b   Gene Expression Quantification
# 232552  b42c5f8b-f027-46a6-9485-80d65664b3c8  miRNA Expression Quantification
#
#                   data_category experimental_strategy
# 0          Structural Variation               RNA-Seq
# 1       Transcriptome Profiling               RNA-Seq
# 2       Transcriptome Profiling               RNA-Seq
# 3          Structural Variation               RNA-Seq
# 4          Structural Variation               RNA-Seq
# ...                         ...                   ...
# 232548     Structural Variation               RNA-Seq
# 232549  Transcriptome Profiling               RNA-Seq
# 232550         Sequencing Reads               RNA-Seq
# 232551  Transcriptome Profiling               RNA-Seq
# 232552  Transcriptome Profiling             miRNA-Seq
#
# [232553 rows x 7 columns]
