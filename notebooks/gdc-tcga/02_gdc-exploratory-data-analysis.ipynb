# %% [markdown]
# # **Exploratory Data Analysis of GDC API Data**
# GDC: Genomic Data Commons

# %% [markdown]
# # Importing Libraries

# %%
import json
import os
import re

import pandas as pd
import requests

# %% [markdown]
# # Constants and Paths

# %%
# Base URL HTML from GDC API
GDC_API_URL = 'https://api.gdc.cancer.gov'

# Endpoint for files download
DATA_ENDPOINT = f'{GDC_API_URL}/data'

# Endpoint of files related to cases
FILES_ENDPOINT = f'{GDC_API_URL}/files'

# Data folder path
DATA_PATH = '../../data'

# External data folder path
EXTERNAL_DATA_PATH = f'{DATA_PATH}/external/gdc-tcga'

# Interim data folder path
INTERIM_DATA_PATH = f'{DATA_PATH}/interim/gdc-tcga'

# %% [markdown]
# # Data Loading

# %%
# DataFrame with the cases of interest
df_cases = pd.read_csv(
    f'{INTERIM_DATA_PATH}/gdc-cases-of-interest.csv'
)

# DataFrame with the files of interest
df_files = pd.read_csv(
    f'{INTERIM_DATA_PATH}/gdc-files-of-interest.csv'
)

# %% [markdown]
# # Files Quantification

# %%
# Columns used in aggregation
columns = [
    'access',
    'experimental_strategy',
    'data_category',
    'data_type',
    'data_format'
]

# Aggregate data about files and count them
df_files_agg = df_files \
    .groupby(columns) \
    .agg(count=pd.NamedAgg(column='file_id', aggfunc='count'))

# Make a normalized count of the files
df_files_agg['%count'] = df_files_agg['count'] / df_files_agg['count'].sum()
df_files_agg['%count'] = (df_files_agg['%count'] * 100).round(2)

# Print the result of aggregation
df_files_agg
# Out:
#                                                                                                         count  \
# access     experimental_strategy data_category           data_type                         data_format
# controlled RNA-Seq               Sequencing Reads        Aligned Reads                     BAM          59954
#                                  Structural Variation    Transcript Fusion                 BEDPE        39538
#                                                                                            TSV          37403
#                                  Transcriptome Profiling Splice Junction Quantification    TSV          20412
#            miRNA-Seq             Sequencing Reads        Aligned Reads                     BAM          18278
# open       RNA-Seq               Transcriptome Profiling Gene Expression Quantification    TSV          20412
#            miRNA-Seq             Transcriptome Profiling Isoform Expression Quantification TSV           6617
#                                                                                            TXT          11661
#                                                          miRNA Expression Quantification   TSV           6617
#                                                                                            TXT          11661
#
#                                                                                                         %count
# access     experimental_strategy data_category           data_type                         data_format
# controlled RNA-Seq               Sequencing Reads        Aligned Reads                     BAM           25.78
#                                  Structural Variation    Transcript Fusion                 BEDPE         17.00
#                                                                                            TSV           16.08
#                                  Transcriptome Profiling Splice Junction Quantification    TSV            8.78
#            miRNA-Seq             Sequencing Reads        Aligned Reads                     BAM            7.86
# open       RNA-Seq               Transcriptome Profiling Gene Expression Quantification    TSV            8.78
#            miRNA-Seq             Transcriptome Profiling Isoform Expression Quantification TSV            2.85
#                                                                                            TXT            5.01
#                                                          miRNA Expression Quantification   TSV            2.85
#                                                                                            TXT            5.01

# %% [markdown]
# # Cases and Files
# Transcriptome Profiling Open Files

# %%
# Define the filtering condition
condition = '(data_category == "Transcriptome Profiling") and (access == "open")'

# Filter files and retrieve case informations
df_files_and_cases = df_files \
    .query(condition) \
    .reset_index(drop=True) \
    .merge(right=df_cases, on='case_id', how='inner')

# %% [markdown]
# ## Primary Sites by Case

# %%
# Aggregate cases according to their primary sites and count them
df_files_and_cases \
    .groupby(['case_id', 'primary_site']) \
    .agg(distinct_sites=pd.NamedAgg(column='primary_site', aggfunc='nunique')) \
    .sort_values(by='distinct_sites', ascending=False)
# Out:
#                                                                                     distinct_sites
# case_id                              primary_site
# 0004d251-3f70-4395-b175-c94c2f5b1b81 Liver and intrahepatic bile ducts                           1
# aadcf26b-c398-489f-a86a-e8db1b5db456 Bladder                                                     1
# aaea5f9c-b35b-47f8-93cb-bdc7b81844ff Breast                                                      1
# aaeb1d59-d6ce-4422-9639-f1e83c002d84 Prostate gland                                              1
# aaee2c46-a0c1-4494-9d7f-c98b15a890d9 Hematopoietic and reticuloendothelial systems               1
# ...                                                                                            ...
# 54d21956-25e4-42df-adbe-6907721fc4b5 Heart, mediastinum, and pleura                              1
# 54d9a54a-7f5d-4ce4-a1a2-edcb0d3389fd Hematopoietic and reticuloendothelial systems               1
# 54d9fa54-0508-4d83-babd-02151ebc24c5 Hematopoietic and reticuloendothelial systems               1
# 54dab158-eb39-4334-8b5a-bf290e6b8bb1 Other and unspecified parts of tongue                       1
# fffdb1d9-58d1-425c-ac12-1e1e5f443bf7 Thyroid gland                                               1
#
# [16789 rows x 1 columns]

# %% [markdown]
# ## Disease Types by Case

# %%
# Aggregate cases according to their disease types and count them
df_files_and_cases \
    .groupby(['case_id', 'disease_type']) \
    .agg(distinct_diseases=pd.NamedAgg(column='disease_type', aggfunc='nunique')) \
    .sort_values(by='distinct_diseases', ascending=False)
# Out:
#                                                                    distinct_diseases
# case_id                              disease_type
# 0004d251-3f70-4395-b175-c94c2f5b1b81 Adenomas and Adenocarcinomas                  1
# aadb8624-dbd7-424a-ab0b-ed326c088c70 Adenomas and Adenocarcinomas                  1
# aae0fca8-99e9-4fde-a2e9-b0ea500737f8 Adenomas and Adenocarcinomas                  1
# aaea5f9c-b35b-47f8-93cb-bdc7b81844ff Ductal and Lobular Neoplasms                  1
# aaeb1d59-d6ce-4422-9639-f1e83c002d84 Adenomas and Adenocarcinomas                  1
# ...                                                                              ...
# 54d21956-25e4-42df-adbe-6907721fc4b5 Mesothelial Neoplasms                         1
# 54d9a54a-7f5d-4ce4-a1a2-edcb0d3389fd Myeloid Leukemias                             1
# 54d9fa54-0508-4d83-babd-02151ebc24c5 Myeloid Leukemias                             1
# 54dab158-eb39-4334-8b5a-bf290e6b8bb1 Squamous Cell Neoplasms                       1
# fffdb1d9-58d1-425c-ac12-1e1e5f443bf7 Adenomas and Adenocarcinomas                  1
#
# [16788 rows x 1 columns]

# %% [markdown]
# ## Files by Case

# %%
# Aggregate cases according to the data type of the files and count them
df_files_and_cases \
    .groupby(['case_id', 'data_type']) \
    .agg(distinct_files=pd.NamedAgg(column='file_id', aggfunc='nunique')) \
    .sort_values(by='distinct_files', ascending=False)
# Out:
#                                                                         distinct_files
# case_id                              data_type
# 842402de-519e-4588-ad49-19df18db899b Gene Expression Quantification                  8
# 3a4afbe7-60d6-4a0d-8166-56a04ff127b0 Gene Expression Quantification                  8
# 9ff6d022-6e23-4f44-a480-1b61929e6ee3 Gene Expression Quantification                  6
#                                      Isoform Expression Quantification               6
#                                      miRNA Expression Quantification                 6
# ...                                                                                ...
# 5c48e21f-1fe9-4007-9b0c-7ca766586fff miRNA Expression Quantification                 1
# 5c4aebeb-fb6f-4d66-b24a-89ef20de971e Gene Expression Quantification                  1
#                                      Isoform Expression Quantification               1
#                                      miRNA Expression Quantification                 1
# fffdb1d9-58d1-425c-ac12-1e1e5f443bf7 miRNA Expression Quantification                 1
#
# [47846 rows x 1 columns]

# %%
# Calculate the number of cases with more than one associated miRNA-Seq or RNA-Seq file
df_files_and_cases \
    .groupby(['case_id', 'data_type']) \
    .agg(distinct_files=pd.NamedAgg(column='file_id', aggfunc='nunique')) \
    .query('distinct_files > 1') \
    .reset_index() \
    .value_counts(subset='case_id') \
    .count()
# Out:
# 3433

# %% [markdown]
# ## Files by Primary Site

# %%
# Aggregate files according to their primary site and count them
df_files_and_cases \
    .groupby('primary_site') \
    .agg(distinct_files=pd.NamedAgg(column='file_id', aggfunc='nunique')) \
    .sort_values(by='distinct_files', ascending=False) \
    .reset_index()
# Out:
#                                          primary_site  distinct_files
# 0       Hematopoietic and reticuloendothelial systems            9753
# 1                                   Bronchus and lung            5483
# 2                                              Kidney            5465
# 3                                       Thyroid gland            4630
# 4                                              Breast            4019
# 5                                               Brain            3509
# 6                                               Colon            1997
# 7                                        Corpus uteri            1845
# 8                                               Ovary            1784
# 9                                      Prostate gland            1656
# 10                                       Cervix uteri            1503
# 11                                            Stomach            1498
# 12                  Liver and intrahepatic bile ducts            1411
# 13                                           Pancreas            1397
# 14                                            Bladder            1305
# 15                                        Uterus, NOS            1252
# 16                                          Esophagus             740
# 17                                        Lymph nodes             712
# 18                                      Adrenal gland             707
# 19    Connective, subcutaneous and other soft tissues             626
# 20                        Other and ill-defined sites             607
# 21                                               Skin             526
# 22                                             Testis             471
# 23              Other and unspecified parts of tongue             437
# 24                     Retroperitoneum and peritoneum             407
# 25                                             Larynx             392
# 26                     Heart, mediastinum, and pleura             381
# 27                                             Rectum             346
# 28                                             Thymus             257
# 29  Other and ill-defined sites in lip, oral cavit...             249
# 30                              Rectosigmoid junction             247
# 31                                     Eye and adnexa             240
# 32                                            Unknown             220
# 33                                     Floor of mouth             180
# 34               Other and unspecified parts of mouth             132
# 35                                             Tonsil             125
# 36                                     Base of tongue              81
# 37        Other and unspecified female genital organs              63
# 38       Other and unspecified parts of biliary tract              57
# 39                                    Small intestine              45
# 40                                         Oropharynx              36
# 41                                                Gum              33
# 42  Bones, joints and articular cartilage of other...              26
# 43                                                Lip              26
# 44                                        Hypopharynx              24
# 45  Spinal cord, cranial nerves, and other parts o...              12
# 46                                             Palate              12
# 47     Bones, joints and articular cartilage of limbs               6
# 48               Other and unspecified urinary organs               6
# 49                                             Vagina               3
# 50                                Anus and anal canal               3
# 51                                        Gallbladder               3
# 52     Peripheral nerves and autonomic nervous system               3
# 53                                           Meninges               3
# 54                        Nasal cavity and middle ear               3
# 55      Other endocrine glands and related structures               3
# 56          Other and unspecified male genital organs               3
# 57        Other and unspecified major salivary glands               3
# 58                                              Vulva               3
# 59                                      Parotid gland               1

# %% [markdown]
# # Files
# Case ID: 9ff6d022-6e23-4f44-a480-1b61929e6ee3

# %% [markdown]
# ## Samples

# %%
# Fields of interest for the endpoint request
fields = [
    'access',
    'cases.samples.tissue_type',
    'cases.samples.tumor_descriptor',
    'cases.samples.sample_type',
    'created_datetime',
    'data_category',
    'data_format',
    'data_type',
    'experimental_strategy',
    'updated_datetime'
]
fields = ','.join(fields)

# List of UUIDs of files of interest
file_ids = df_files \
    .query('case_id == "9ff6d022-6e23-4f44-a480-1b61929e6ee3"') \
    ['file_id'].to_list()

# Initializa the files DataFrame for this case
df_files_info = pd.DataFrame()

# Request informations about the files of interest to the endpoint
for file_id in file_ids:
    # Filter used in the endpoint request
    filter = {
        'op': '=',
        'content': {
            'field': 'file_id',
            'value': file_id
        }
    }

    # Parameters for the endpoint request
    params = {
        'fields': fields,
        'filters': filter,
        'size': '1'
    }

    # Request file information to the endpoint
    response = requests.post(
        url=FILES_ENDPOINT,
        headers={'Content-Type': 'application/json'},
        json=params
    )

    # Transform the response content to a DataFrame
    json_response = json.loads(response.content.decode('utf-8'))
    df_file_info = pd.json_normalize(json_response['data']['hits'])

    # Concatenate the cases of this project with the others
    if df_files_info.empty == False:
        df_files_info = pd.concat([df_files_info, df_file_info], ignore_index=True)
    else:
        df_files_info = df_file_info.copy()

# %%
# Print the records of interest from the DataFrame
pd.set_option('display.max_colwidth', 100)
df_files_info \
    .query('data_category == "Transcriptome Profiling"') \
    .sort_values(by=['data_type', 'created_datetime']) \
    .reset_index(drop=True) \
    [[
        'id',
        'data_type',
        'cases',
        'created_datetime',
        'updated_datetime'
    ]]
# Out:
#                                       id                          data_type  \
# 0   b96247db-6f2a-4d26-9ac4-142e1c079e0e     Gene Expression Quantification
# 1   93c8678d-7afd-4be2-92cb-c39ad7701b43     Gene Expression Quantification
# 2   d12e199e-8471-4f60-8da2-2b479db61ab4     Gene Expression Quantification
# 3   167073fa-9e38-4f8d-af1f-301ed3a8b5f7     Gene Expression Quantification
# 4   c54a604e-9379-46f1-938c-e2d09f8538d8     Gene Expression Quantification
# 5   ceb4dd9b-6f10-4358-8312-3b126952d3cc     Gene Expression Quantification
# 6   0cf6cded-942f-4141-a4a5-35afb7082f37  Isoform Expression Quantification
# 7   d39cc122-925b-4292-9fe1-cab1d031bbd7  Isoform Expression Quantification
# 8   0afd73ac-8fbc-418f-9d58-b1da06da4c98  Isoform Expression Quantification
# 9   c22a38cc-064b-46b8-a576-2fcbcfec7ceb  Isoform Expression Quantification
# 10  2d33a6eb-3db9-49e4-85f2-5a3387c21cf5  Isoform Expression Quantification
# 11  229a4e0b-1bf1-4432-9cda-864dcbfaea55  Isoform Expression Quantification
# 12  a315cf50-82df-48a7-8aef-04d6add435db     Splice Junction Quantification
# 13  e8440d1f-0f9b-40ac-9bd1-4f99149420ec     Splice Junction Quantification
# 14  2468af99-5e63-4b2c-8779-c397bd2db4df     Splice Junction Quantification
# 15  da368934-135a-4a1f-9195-0c46460be504     Splice Junction Quantification
# 16  5fb6004d-7959-4abf-9170-bddaf255985b     Splice Junction Quantification
# 17  2c99fc87-45bd-4f9d-afa5-d98c309eed37     Splice Junction Quantification
# 18  01e3d493-7e2a-4a50-b8cb-2597143a8e1a    miRNA Expression Quantification
# 19  89156bc2-c8f3-47d8-a5c8-11fa535614bb    miRNA Expression Quantification
# 20  62ba65e5-20be-4a62-8126-25d7241c30f3    miRNA Expression Quantification
# 21  fe3e01ae-1265-4baa-837e-8d73e3405021    miRNA Expression Quantification
# 22  cf6be942-0ff5-4be5-92a9-39c1e46cb53d    miRNA Expression Quantification
# 23  3e886ae0-454f-4e26-b7d1-eab5e3c441e4    miRNA Expression Quantification
#
#                                                                                                   cases  \
# 0   [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 1   [{'samples': [{'tumor_descriptor': 'Not Applicable', 'sample_type': 'Solid Tissue Normal', 'tiss...
# 2   [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 3   [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 4   [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 5   [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 6   [{'samples': [{'tumor_descriptor': 'Not Applicable', 'sample_type': 'Solid Tissue Normal', 'tiss...
# 7   [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 8   [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 9   [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 10  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 11  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 12  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 13  [{'samples': [{'tumor_descriptor': 'Not Applicable', 'sample_type': 'Solid Tissue Normal', 'tiss...
# 14  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 15  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 16  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 17  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 18  [{'samples': [{'tumor_descriptor': 'Not Applicable', 'sample_type': 'Solid Tissue Normal', 'tiss...
# 19  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 20  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 21  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 22  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
# 23  [{'samples': [{'tumor_descriptor': 'Primary', 'sample_type': 'Primary Tumor', 'tissue_type': 'Tu...
#
#                     created_datetime                  updated_datetime
# 0   2022-01-06T09:46:53.769541-06:00  2024-07-30T21:45:03.814480-05:00
# 1   2022-01-06T09:46:56.688571-06:00  2024-07-30T21:47:29.474323-05:00
# 2   2022-01-06T09:47:32.472999-06:00  2024-07-30T21:53:34.939697-05:00
# 3   2022-01-06T09:47:37.123345-06:00  2024-07-30T21:41:07.815061-05:00
# 4   2022-01-06T09:47:57.280420-06:00  2024-07-30T21:43:27.830713-05:00
# 5   2022-01-06T09:55:35.726930-06:00  2024-07-30T21:41:18.605327-05:00
# 6   2019-10-10T11:23:13.777284-05:00  2024-07-29T13:21:12.651533-05:00
# 7   2019-12-13T08:15:27.709025-06:00  2024-07-29T10:48:30.938949-05:00
# 8   2020-10-16T17:02:06.560539-05:00  2024-07-29T15:23:17.906969-05:00
# 9   2020-10-16T17:06:28.600735-05:00  2024-07-29T15:24:06.021117-05:00
# 10  2020-10-16T17:23:11.241989-05:00  2024-07-29T12:55:10.921337-05:00
# 11  2020-10-16T17:26:47.098094-05:00  2024-07-29T15:26:09.120335-05:00
# 12  2022-01-06T09:46:55.226032-06:00  2024-07-30T17:47:51.598456-05:00
# 13  2022-01-06T09:46:58.278306-06:00  2024-07-30T17:46:51.265291-05:00
# 14  2022-01-06T09:47:34.173756-06:00  2024-07-30T17:43:06.925765-05:00
# 15  2022-01-06T09:47:35.576803-06:00  2024-07-30T17:52:41.242554-05:00
# 16  2022-01-06T09:47:55.927745-06:00  2024-07-30T02:16:37.504378-05:00
# 17  2022-01-06T09:55:37.090155-06:00  2024-07-30T17:55:33.528087-05:00
# 18  2019-10-10T11:41:45.312973-05:00  2024-07-29T14:48:02.906487-05:00
# 19  2019-12-13T08:07:43.882221-06:00  2024-07-29T11:27:26.461180-05:00
# 20  2020-10-16T17:02:11.955328-05:00  2024-07-29T13:01:31.511772-05:00
# 21  2020-10-16T17:06:31.331164-05:00  2024-07-29T15:24:04.201210-05:00
# 22  2020-10-16T17:23:29.795343-05:00  2024-07-29T13:01:57.302137-05:00
# 23  2020-10-16T17:26:51.214857-05:00  2024-07-29T15:26:19.820757-05:00

# %% [markdown]
# ## Download

# %%
# UUIDs of files of interest
file_ids = [
    'b96247db-6f2a-4d26-9ac4-142e1c079e0e', # Gene Expression Quantification
    '0cf6cded-942f-4141-a4a5-35afb7082f37', # Isoform Expression Quantification
    '01e3d493-7e2a-4a50-b8cb-2597143a8e1a'  # miRNA Expression Quantification
]

# Download each of the files of interest
for file_id in file_ids:
    # Request file download to the endpoint
    response = requests.get(
        url=f'{DATA_ENDPOINT}/{file_id}', 
        headers={'Content-Type': 'application/json'}
    )

    # Get the file name from endpoint response
    response_head_cd = response.headers['Content-Disposition']
    file_name = re.findall('filename=(.+)', response_head_cd)[0]

    # Store the file in the external data folder
    file_path = os.path.join(EXTERNAL_DATA_PATH, file_name)
    with open(file_path, 'wb') as output_file:
        output_file.write(response.content)
